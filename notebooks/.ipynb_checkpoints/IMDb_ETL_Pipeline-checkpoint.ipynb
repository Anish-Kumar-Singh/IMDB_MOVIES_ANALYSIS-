# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("IMDb ETL Project Started!")
# Out:
# IMDb ETL Project Started!

# %%
df=pd.read_csv("../data/raw/imdb_movies.csv")

# %%
df.head()
# Out:
#    movie_id    title     genre  rating  budget_million  gross_million  \
# 0       1.0  Movie 1  Thriller     4.2           100.0            NaN
# 1       2.0  Movie 2    Sci-Fi     7.8           150.0          150.0
# 2       3.0  Movie 3  Thriller     4.9            30.0          600.0
# 3       4.0  Movie 4  Thriller     9.1           100.0          600.0
# 4       5.0  Movie 5    Sci-Fi     4.5            10.0          600.0
#
#     director lead_actor  release_year
# 0    Cameron        NaN        2017.0
# 1      Nolan    Actor B        2019.0
# 2  Spielberg    Actor D        2016.0
# 3  Rajamouli    Actor D        2015.0
# 4    Cameron    Actor C        2022.0

# %%
df.shape
# Out:
# (5500, 9)

# %%
df.columns
# Out:
# Index(['movie_id', 'title', 'genre', 'rating', 'budget_million',
#        'gross_million', 'director', 'lead_actor', 'release_year'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        5177 non-null   float64
#  1   title           5500 non-null   str
#  2   genre           5500 non-null   str
#  3   rating          5211 non-null   float64
#  4   budget_million  4569 non-null   float64
#  5   gross_million   4583 non-null   float64
#  6   director        4720 non-null   str
#  7   lead_actor      4586 non-null   str
#  8   release_year    4886 non-null   float64
# dtypes: float64(5), str(4)
# memory usage: 386.8 KB

# %%
df.isnull().sum()
# Out:
# movie_id          323
# title               0
# genre               0
# rating            289
# budget_million    931
# gross_million     917
# director          780
# lead_actor        914
# release_year      614
# dtype: int64

# %% [markdown]
# A movie is duplicate when title + release_year is repeated.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.duplicated(subset=["title","release_year"]).sum()
# Out:
# np.int64(27)

# %% [markdown]
# 27 duplicates

# %%
# duplicates=df[df.duplicated(subset=["title","release_year"],keep=False)]

# %%
df=df.sort_values(by=['title','release_year','rating','gross_million'],ascending=[True,True,False,False])

# %%
df
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 0          1.0     Movie 1  Thriller     4.2           100.0            NaN
# 9         10.0    Movie 10    Sci-Fi     5.0             NaN           20.0
# 1000    1001.0  Movie 1001    Comedy     6.4             NaN           20.0
# 1001    1002.0  Movie 1002    Comedy     7.6            60.0          150.0
# 1002       NaN  Movie 1003    Sci-Fi     9.1           150.0          150.0
# ...        ...         ...       ...     ...             ...            ...
# 995      996.0   Movie 996     Drama     4.5           150.0           80.0
# 996      997.0   Movie 997    Horror     6.3           150.0          300.0
# 997      998.0   Movie 998   Romance     6.9            10.0            NaN
# 999     1000.0   Movie 999    Horror     8.0            10.0          600.0
# 998      999.0   Movie 999  Thriller     4.8           100.0           20.0
#
#        director lead_actor  release_year
# 0       Cameron        NaN        2017.0
# 9     Spielberg    Actor B        2019.0
# 1000  Rajamouli    Actor D        2021.0
# 1001    Cameron        NaN           NaN
# 1002  Spielberg    Actor C        2019.0
# ...         ...        ...           ...
# 995     Cameron    Actor B        2020.0
# 996         NaN    Actor B        2019.0
# 997       Nolan    Actor B        2022.0
# 999   Tarantino    Actor A        2019.0
# 998     Cameron    Actor A        2020.0
#
# [5500 rows x 9 columns]

# %%
a=df[df.duplicated(subset=['title','release_year'],keep=False)]

# %%
a
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 1124    1125.0  Movie 1124   Fantasy     8.5             NaN          150.0
# 1123    1124.0  Movie 1124   Romance     4.8            30.0          600.0
# 1374    1375.0  Movie 1374   Romance     6.1           100.0          150.0
# 1373    1374.0  Movie 1374   Romance     4.3            10.0           80.0
# 174      175.0   Movie 174    Action     7.9            30.0           80.0
# 173      174.0   Movie 174    Sci-Fi     4.1           100.0          600.0
# 1999    2000.0  Movie 1999   Fantasy     9.4            10.0          150.0
# 1998    1999.0  Movie 1999  Thriller     7.4           150.0           80.0
# 2098    2099.0  Movie 2099    Comedy     8.2           100.0           80.0
# 2099    2100.0  Movie 2099  Thriller     7.2            30.0            NaN
# 2198    2199.0  Movie 2199    Sci-Fi     6.2             NaN            NaN
# 2199    2200.0  Movie 2199     Drama     5.1            30.0          600.0
# 2349    2350.0  Movie 2349    Comedy     9.3            30.0           20.0
# 2348    2349.0  Movie 2349    Horror     6.6            10.0          150.0
# 23        24.0    Movie 24     Drama     5.6           100.0          300.0
# 24        25.0    Movie 24    Horror     5.3            30.0           80.0
# 2724    2725.0  Movie 2724   Fantasy     8.8            60.0           80.0
# 2723    2724.0  Movie 2724    Sci-Fi     7.0            60.0          300.0
# 2824    2825.0  Movie 2824    Action     9.0           100.0            NaN
# 2823    2824.0  Movie 2824     Drama     8.7             NaN          150.0
# 2848    2849.0  Movie 2849    Action     6.0            30.0           80.0
# 2849    2850.0  Movie 2849   Fantasy     NaN            30.0          150.0
# 299      300.0   Movie 299    Sci-Fi     7.9             NaN           20.0
# 298      299.0   Movie 299   Fantasy     7.7           100.0          150.0
# 2998    2999.0  Movie 2999   Romance     4.8            30.0           20.0
# 2999    3000.0  Movie 2999   Romance     3.9            60.0          300.0
# 3024    3025.0  Movie 3024    Sci-Fi     4.9             NaN          600.0
# 3023    3024.0  Movie 3024   Fantasy     3.6            60.0          300.0
# 3223    3224.0  Movie 3224    Action     7.6             NaN          150.0
# 3224    3225.0  Movie 3224    Horror     4.3           150.0          600.0
# 3374    3375.0  Movie 3374    Action     8.4            60.0           20.0
# 3373    3374.0  Movie 3374    Horror     4.6            60.0           20.0
# 3424    3425.0  Movie 3424    Sci-Fi     8.1            30.0           20.0
# 3423    3424.0  Movie 3424  Thriller     6.8           150.0          600.0
# 3498    3499.0  Movie 3499    Action     6.3            60.0           80.0
# 3499    3500.0  Movie 3499   Fantasy     3.7            30.0           80.0
# 3549    3550.0  Movie 3549    Comedy     8.5            60.0          600.0
# 3548    3549.0  Movie 3549   Romance     7.9            60.0            NaN
# 3749    3750.0  Movie 3749    Comedy     6.7           100.0           80.0
# 3748    3749.0  Movie 3749    Sci-Fi     5.7            30.0           80.0
# 4148    4149.0  Movie 4149    Action     4.6             NaN          150.0
# 4149    4150.0  Movie 4149    Comedy     3.8           100.0           20.0
# 4799    4800.0  Movie 4799    Sci-Fi     6.8           100.0          600.0
# 4798    4799.0  Movie 4799    Sci-Fi     5.2             NaN          150.0
# 49        50.0    Movie 49   Fantasy     5.9           100.0           20.0
# 48        49.0    Movie 49    Sci-Fi     4.1           100.0          300.0
# 598      599.0   Movie 599    Horror     5.1            10.0          600.0
# 599      600.0   Movie 599    Sci-Fi     4.0            60.0            NaN
# 674      675.0   Movie 674    Action     7.7            60.0          300.0
# 673      674.0   Movie 674  Thriller     5.6            60.0           20.0
# 723      724.0   Movie 724    Sci-Fi     8.8           100.0           20.0
# 724      725.0   Movie 724    Horror     4.4           150.0            NaN
# 874      875.0   Movie 874    Comedy     8.1            60.0          600.0
# 873      874.0   Movie 874     Drama     NaN             NaN          600.0
#
#        director lead_actor  release_year
# 1124  Tarantino        NaN        2022.0
# 1123   Scorsese    Actor A        2022.0
# 1374        NaN    Actor D        2021.0
# 1373  Spielberg        NaN        2021.0
# 174       Nolan    Actor B           NaN
# 173     Cameron    Actor E           NaN
# 1999    Cameron    Actor A        2015.0
# 1998        NaN        NaN        2015.0
# 2098        NaN    Actor D        2015.0
# 2099        NaN    Actor D        2015.0
# 2198      Nolan    Actor A        2022.0
# 2199  Spielberg    Actor B        2022.0
# 2349   Scorsese    Actor C        2021.0
# 2348      Nolan    Actor B        2021.0
# 23    Tarantino    Actor A        2017.0
# 24      Cameron    Actor D        2017.0
# 2724      Nolan    Actor C        2019.0
# 2723  Spielberg    Actor C        2019.0
# 2824  Spielberg        NaN        2017.0
# 2823      Nolan    Actor D        2017.0
# 2848        NaN    Actor B        2022.0
# 2849    Cameron    Actor B        2022.0
# 299         NaN    Actor B        2018.0
# 298         NaN    Actor C        2018.0
# 2998  Spielberg    Actor C        2021.0
# 2999    Cameron    Actor D        2021.0
# 3024   Scorsese    Actor D        2015.0
# 3023      Nolan    Actor D        2015.0
# 3223  Rajamouli    Actor C           NaN
# 3224    Cameron    Actor E           NaN
# 3374  Rajamouli    Actor A        2020.0
# 3373      Nolan    Actor E        2020.0
# 3424      Nolan    Actor B        2022.0
# 3423  Rajamouli        NaN        2022.0
# 3498  Tarantino    Actor A        2019.0
# 3499   Scorsese    Actor A        2019.0
# 3549  Spielberg    Actor B        2022.0
# 3548  Spielberg    Actor A        2022.0
# 3749  Rajamouli    Actor D        2021.0
# 3748  Rajamouli        NaN        2021.0
# 4148  Rajamouli    Actor D           NaN
# 4149  Tarantino    Actor E           NaN
# 4799   Scorsese    Actor C        2017.0
# 4798   Scorsese    Actor B        2017.0
# 49    Rajamouli        NaN        2022.0
# 48    Tarantino    Actor D        2022.0
# 598   Spielberg    Actor B        2022.0
# 599     Cameron    Actor B        2022.0
# 674       Nolan    Actor E        2017.0
# 673     Cameron    Actor E        2017.0
# 723       Nolan        NaN        2017.0
# 724     Cameron    Actor D        2017.0
# 874         NaN    Actor C           NaN
# 873   Tarantino        NaN           NaN

# %%
df=df.drop_duplicates(subset=['title','release_year'],keep='first')

# %%
df
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 0          1.0     Movie 1  Thriller     4.2           100.0            NaN
# 9         10.0    Movie 10    Sci-Fi     5.0             NaN           20.0
# 1000    1001.0  Movie 1001    Comedy     6.4             NaN           20.0
# 1001    1002.0  Movie 1002    Comedy     7.6            60.0          150.0
# 1002       NaN  Movie 1003    Sci-Fi     9.1           150.0          150.0
# ...        ...         ...       ...     ...             ...            ...
# 995      996.0   Movie 996     Drama     4.5           150.0           80.0
# 996      997.0   Movie 997    Horror     6.3           150.0          300.0
# 997      998.0   Movie 998   Romance     6.9            10.0            NaN
# 999     1000.0   Movie 999    Horror     8.0            10.0          600.0
# 998      999.0   Movie 999  Thriller     4.8           100.0           20.0
#
#        director lead_actor  release_year
# 0       Cameron        NaN        2017.0
# 9     Spielberg    Actor B        2019.0
# 1000  Rajamouli    Actor D        2021.0
# 1001    Cameron        NaN           NaN
# 1002  Spielberg    Actor C        2019.0
# ...         ...        ...           ...
# 995     Cameron    Actor B        2020.0
# 996         NaN    Actor B        2019.0
# 997       Nolan    Actor B        2022.0
# 999   Tarantino    Actor A        2019.0
# 998     Cameron    Actor A        2020.0
#
# [5473 rows x 9 columns]

# %% [markdown]
# now check the duplicates are really removed

# %%
df.duplicated(subset=['title','release_year']).sum()
# Out:
# np.int64(0)

# %% [markdown]
# BR-02: Missing Movie ID.

# %%
df['movie_id'].isnull().sum()
# Out:
# np.int64(323)

# %% [markdown]
# **printing the full(nan rows)**
# We need to change:
# **NaN**
# to a new unique ID:
# **105**
# This is called a **surrogate key.**

# %%
df[df['movie_id'].isnull()]
# Out:
#       movie_id       title     genre  rating  budget_million  gross_million  \
# 1002       NaN  Movie 1003    Sci-Fi     9.1           150.0          150.0
# 101        NaN   Movie 102    Sci-Fi     5.1            10.0          300.0
# 1019       NaN  Movie 1020    Action     8.3            60.0          150.0
# 1036       NaN  Movie 1037   Fantasy     5.1            60.0          300.0
# 1053       NaN  Movie 1054    Comedy     5.3             NaN           80.0
# ...        ...         ...       ...     ...             ...            ...
# 917        NaN   Movie 918  Thriller     5.1            30.0            NaN
# 934        NaN   Movie 935  Thriller     5.0            30.0          600.0
# 951        NaN   Movie 952   Romance     6.3           150.0          600.0
# 968        NaN   Movie 969    Sci-Fi     NaN            30.0          600.0
# 985        NaN   Movie 986   Romance     4.3            30.0           80.0
#
#        director lead_actor  release_year
# 1002  Spielberg    Actor C        2019.0
# 101    Scorsese    Actor E        2020.0
# 1019  Tarantino    Actor B           NaN
# 1036      Nolan        NaN        2015.0
# 1053   Scorsese    Actor E        2018.0
# ...         ...        ...           ...
# 917         NaN    Actor C        2022.0
# 934         NaN    Actor B        2017.0
# 951   Rajamouli        NaN        2016.0
# 968         NaN    Actor A        2021.0
# 985       Nolan    Actor E        2018.0
#
# [323 rows x 9 columns]

# %%
max_va=df['movie_id'].max()

# %%
missing_id=df['movie_id'].isnull()

# %% [markdown]
# sum of null values

# %%
sum_null=df["movie_id"].isnull().sum()

# %%
sum_null
# Out:
# np.int64(323)

# %%
missing_id
# Out:
# 0       False
# 9       False
# 1000    False
# 1001    False
# 1002     True
#         ...
# 995     False
# 996     False
# 997     False
# 999     False
# 998     False
# Name: movie_id, Length: 5473, dtype: bool

# %% [markdown]
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.loc[missing_id,"movie_id"]=range(
#       2     max_va+1,
#       3     max_va+1+sum_null)
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer

# %% [markdown]
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer.Replace or remove non-finite values or cast to an integer typethat supports these values (e.g. 'Int64')
# we cant convert the null values to** int type** sooo **first we have to fill the full values then we have to change the type of the column**
# **df['movie_id']=df["movie_id"].astype(int) **in correct at this step

# %%
df.loc[missing_id,"movie_id"]=range(
    int(max_va)+1,
    int(max_va)+1+sum_null)

# %%
df['movie_id']=df['movie_id'].astype(int)

# %%
df.info() # here we can seee the datatype of each column
# Out:
# <class 'pandas.DataFrame'>
# Index: 5473 entries, 0 to 998
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        5473 non-null   int64
#  1   title           5473 non-null   str
#  2   genre           5473 non-null   str
#  3   rating          5186 non-null   float64
#  4   budget_million  4545 non-null   float64
#  5   gross_million   4560 non-null   float64
#  6   director        4696 non-null   str
#  7   lead_actor      4564 non-null   str
#  8   release_year    4863 non-null   float64
# dtypes: float64(4), int64(1), str(4)
# memory usage: 427.6 KB

# %% [markdown]
# **BR-03: Missing Rating
# Rule: Ratings must be between 0 and 10.
# Action:
# Replace NULL ratings with genre-wise average rating.**

# %%
df[(df['rating']<=0)| ( df['rating'] >=10) ]
# Out:
# Empty DataFrame
# Columns: [movie_id, title, genre, rating, budget_million, gross_million, director, lead_actor, release_year]
# Index: []

# %% [markdown]
# **no rows are written then so no rating is out of the constraint**

# %%
gen_rat_avg=df.groupby('genre')["rating"].transform("mean").round(1)

# %%
df['rating'].head(40)
# Out:
# 0       4.2
# 9       5.0
# 1000    6.4
# 1001    7.6
# 1002    9.1
# 1003    7.2
# 1004    4.0
# 1005    9.2
# 1006    NaN
# 1007    7.2
# 1008    5.3
# 100     8.1
# 1009    8.1
# 1010    4.2
# 1011    3.7
# 1012    8.4
# 1013    7.7
# 1014    5.8
# 1015    4.7
# 1016    3.6
# 1017    5.6
# 1018    7.4
# 101     5.1
# 1019    8.3
# 1020    6.2
# 1021    8.9
# 1022    8.1
# 1024    7.7
# 1023    6.2
# 1025    NaN
# 1026    8.7
# 1027    7.6
# 1028    8.7
# 102     8.0
# 1029    8.6
# 1030    8.2
# 1031    6.2
# 1032    5.4
# 1033    6.1
# 1034    8.3
# Name: rating, dtype: float64

# %%
df['rating']=df['rating'].fillna(gen_rat_avg)

# %%
df['rating'].head(40)
# Out:
# 0       4.2
# 9       5.0
# 1000    6.4
# 1001    7.6
# 1002    9.1
# 1003    7.2
# 1004    4.0
# 1005    9.2
# 1006    6.4
# 1007    7.2
# 1008    5.3
# 100     8.1
# 1009    8.1
# 1010    4.2
# 1011    3.7
# 1012    8.4
# 1013    7.7
# 1014    5.8
# 1015    4.7
# 1016    3.6
# 1017    5.6
# 1018    7.4
# 101     5.1
# 1019    8.3
# 1020    6.2
# 1021    8.9
# 1022    8.1
# 1024    7.7
# 1023    6.2
# 1025    6.5
# 1026    8.7
# 1027    7.6
# 1028    8.7
# 102     8.0
# 1029    8.6
# 1030    8.2
# 1031    6.2
# 1032    5.4
# 1033    6.1
# 1034    8.3
# Name: rating, dtype: float64

# %% [markdown]
# checking the full values are filled or not

# %%
df['rating'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# BR-04: Missing Director / Actor
# **Rule: Director and lead actor are mandatory descriptive attributes.**
# Action:
# **Replace NULL values with 'Unknown'.**

# %%
df['director'].isnull().sum()
# Out:
# np.int64(777)

# %%
df['lead_actor'].isnull().sum()
# Out:
# np.int64(909)

# %%
df['director']=df['director'].fillna('unknown')

# %%
df['lead_actor']=df['lead_actor'].fillna('unknown')

# %% [markdown]
# checking the full values again in the two column

# %%
print("missing value of directors:",df['director'].isnull().sum())
print("missing value of lead actor:",df['lead_actor'].isnull().sum())
# Out:
# missing value of directors: 0
# missing value of lead actor: 0

# %% [markdown]
# I am adding the one more column which can help full while creating the dashboard

# %%
df.isnull().sum()
# Out:
# movie_id            0
# title               0
# genre               0
# rating              0
# budget_million    928
# gross_million     913
# director            0
# lead_actor          0
# release_year      610
# dtype: int64

# %%
df['budget_million']=df['budget_million'].fillna(0)

# %%
df.isnull().sum()
# Out:
# movie_id             0
# title                0
# genre                0
# rating               0
# budget_million       0
# gross_million      913
# director             0
# lead_actor           0
# release_year       610
# budget_million       0
# dtype: int64

# %%
df['gross_million']=df['gross_million'].fillna(0)

# %%
df.isnull().sum()
# Out:
# movie_id            0
# title               0
# genre               0
# rating              0
# budget_million      0
# gross_million       0
# director            0
# lead_actor          0
# release_year      610
# dtype: int64

# %%
df['release_year']=df['release_year'].fillna(df.groupby('genre')['release_year'].transform("median"))

# %%
df.isnull().sum()
# Out:
# movie_id          0
# title             0
# genre             0
# rating            0
# budget_million    0
# gross_million     0
# director          0
# lead_actor        0
# release_year      0
# dtype: int64

# %%
df['profit_million'] = df['gross_million'] - df['budget_million']

# %%
del df['budget_million ']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'budget_million '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 del df['budget_million ']
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:4338, in NDFrame.__delitem__(self, key)
#    4333             deleted = True
#    4334 if not deleted:
#    4335     # If the above loop ran and didn't delete anything because
#    4336     # there was no match, this call should raise the appropriate
#    4337     # exception:
# -> 4338     loc = self.axes[-1].get_loc(key)
#    4339     self._mgr = self._mgr.idelete(loc)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'budget_million '

# %%
df.isnull().sum()
# Out:
# movie_id          0
# title             0
# genre             0
# rating            0
# budget_million    0
# gross_million     0
# director          0
# lead_actor        0
# release_year      0
# profit_million    0
# dtype: int64

# %%
df.to_csv("../data/clean/imdb_movies_cleaned.csv",index=False)

# %%
df['gross_million'].describe()
# Out:
# count    5473.000000
# mean      191.019551
# std       208.012521
# min         0.000000
# 25%        20.000000
# 50%       150.000000
# 75%       300.000000
# max       600.000000
# Name: gross_million, dtype: float64

# %%
df['gross_million'].value_counts().head(20)
# Out:
# gross_million
# 150.0    941
# 20.0     930
# 600.0    916
# 0.0      913
# 80.0     890
# 300.0    883
# Name: count, dtype: int64

# %%
print("Minimum:", df['gross_million'].min())
print("Maximum:", df['gross_million'].max())
# Out:
# Minimum: 20.0
# Maximum: 600.0

# %% [markdown]
# PS C:\Users\anish> python -m pip install mysql-connector-python( connect to the sql)

# %%
import mysql.connector

# %%
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="1234",
    database="imdb_analytics"
)

# %%
print(connection.is_connected()) # checking the connection
# Out:
# True

# %% [markdown]
# insert the record

# %%
cursor = connection.cursor()

# %%
insert_query = """
INSERT INTO movies
(movie_id, title, genre, rating, budget_million,
 gross_million, profit_million, director, lead_actor, release_year)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# %% [markdown]
# %s is the placeholder

# %%
data=list(df[['movie_id', 'title', 'genre', 'rating', 'budget_million',
 'gross_million', 'profit_million', 'director', 'lead_actor', 'release_year']].itertuples(index=False,name=None))

# %%
cursor.close()
connection.close()

# %%
data
# Out:
# [(1,
#   'Movie 1',
#   'Thriller',
#   4.2,
#   100.0,
#   150.0,
#   50.0,
#   'Cameron',
#   'unknown',
#   2017.0),
#  (10,
#   'Movie 10',
#   'Sci-Fi',
#   5.0,
#   60.0,
#   20.0,
#   -40.0,
#   'Spielberg',
#   'Actor B',
#   2019.0),
#  (1001,
#   'Movie 1001',
#   'Comedy',
#   6.4,
#   60.0,
#   20.0,
#   -40.0,
#   'Rajamouli',
#   'Actor D',
#   2021.0),
#  (1002,
#   'Movie 1002',
#   'Comedy',
#   7.6,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'unknown',
#   2019.0),
#  (5501,
#   'Movie 1003',
#   'Sci-Fi',
#   9.1,
#   150.0,
#   150.0,
#   0.0,
#   'Spielberg',
#   'Actor C',
#   2019.0),
#  (1004,
#   'Movie 1004',
#   'Action',
#   7.2,
#   10.0,
#   80.0,
#   70.0,
#   'unknown',
#   'Actor B',
#   2015.0),
#  (1005,
#   'Movie 1005',
#   'Thriller',
#   4.0,
#   30.0,
#   150.0,
#   120.0,
#   'Spielberg',
#   'Actor D',
#   2015.0),
#  (1006,
#   'Movie 1006',
#   'Horror',
#   9.2,
#   60.0,
#   300.0,
#   240.0,
#   'unknown',
#   'Actor D',
#   2021.0),
#  (1007,
#   'Movie 1007',
#   'Horror',
#   6.4,
#   30.0,
#   300.0,
#   270.0,
#   'Rajamouli',
#   'Actor A',
#   2015.0),
#  (1008,
#   'Movie 1008',
#   'Horror',
#   7.2,
#   60.0,
#   150.0,
#   90.0,
#   'Spielberg',
#   'Actor A',
#   2018.0),
#  (1009,
#   'Movie 1009',
#   'Action',
#   5.3,
#   10.0,
#   20.0,
#   10.0,
#   'Rajamouli',
#   'Actor D',
#   2015.0),
#  (101,
#   'Movie 101',
#   'Sci-Fi',
#   8.1,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'Actor D',
#   2020.0),
#  (1010,
#   'Movie 1010',
#   'Comedy',
#   8.1,
#   60.0,
#   80.0,
#   20.0,
#   'Scorsese',
#   'Actor C',
#   2022.0),
#  (1011,
#   'Movie 1011',
#   'Comedy',
#   4.2,
#   150.0,
#   300.0,
#   150.0,
#   'Scorsese',
#   'unknown',
#   2017.0),
#  (1012,
#   'Movie 1012',
#   'Sci-Fi',
#   3.7,
#   30.0,
#   150.0,
#   120.0,
#   'Cameron',
#   'Actor A',
#   2019.0),
#  (1013,
#   'Movie 1013',
#   'Sci-Fi',
#   8.4,
#   150.0,
#   300.0,
#   150.0,
#   'Spielberg',
#   'Actor D',
#   2018.0),
#  (1014,
#   'Movie 1014',
#   'Drama',
#   7.7,
#   60.0,
#   300.0,
#   240.0,
#   'Nolan',
#   'unknown',
#   2022.0),
#  (1015,
#   'Movie 1015',
#   'Romance',
#   5.8,
#   30.0,
#   20.0,
#   -10.0,
#   'Nolan',
#   'Actor A',
#   2015.0),
#  (1016,
#   'Movie 1016',
#   'Romance',
#   4.7,
#   10.0,
#   600.0,
#   590.0,
#   'Nolan',
#   'Actor A',
#   2020.0),
#  (1017,
#   'Movie 1017',
#   'Action',
#   3.6,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'Actor B',
#   2015.0),
#  (1018,
#   'Movie 1018',
#   'Action',
#   5.6,
#   60.0,
#   80.0,
#   20.0,
#   'unknown',
#   'unknown',
#   2019.0),
#  (1019,
#   'Movie 1019',
#   'Romance',
#   7.4,
#   100.0,
#   80.0,
#   -20.0,
#   'unknown',
#   'Actor D',
#   2017.0),
#  (5502,
#   'Movie 102',
#   'Sci-Fi',
#   5.1,
#   10.0,
#   300.0,
#   290.0,
#   'Scorsese',
#   'Actor E',
#   2020.0),
#  (5503,
#   'Movie 1020',
#   'Action',
#   8.3,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor B',
#   2019.0),
#  (1021,
#   'Movie 1021',
#   'Sci-Fi',
#   6.2,
#   10.0,
#   80.0,
#   70.0,
#   'Scorsese',
#   'unknown',
#   2018.0),
#  (1022,
#   'Movie 1022',
#   'Horror',
#   8.9,
#   30.0,
#   150.0,
#   120.0,
#   'Rajamouli',
#   'Actor C',
#   2022.0),
#  (1023,
#   'Movie 1023',
#   'Horror',
#   8.1,
#   100.0,
#   150.0,
#   50.0,
#   'Cameron',
#   'unknown',
#   2022.0),
#  (1025,
#   'Movie 1024',
#   'Horror',
#   7.7,
#   30.0,
#   20.0,
#   -10.0,
#   'Spielberg',
#   'Actor B',
#   2019.0),
#  (1024,
#   'Movie 1024',
#   'Sci-Fi',
#   6.2,
#   60.0,
#   300.0,
#   240.0,
#   'Spielberg',
#   'unknown',
#   2020.0),
#  (1026,
#   'Movie 1026',
#   'Romance',
#   6.5,
#   100.0,
#   20.0,
#   -80.0,
#   'Spielberg',
#   'Actor B',
#   2020.0),
#  (1027,
#   'Movie 1027',
#   'Drama',
#   8.7,
#   60.0,
#   300.0,
#   240.0,
#   'Scorsese',
#   'Actor C',
#   2022.0),
#  (1028,
#   'Movie 1028',
#   'Thriller',
#   7.6,
#   60.0,
#   20.0,
#   -40.0,
#   'Tarantino',
#   'Actor C',
#   2020.0),
#  (1029,
#   'Movie 1029',
#   'Fantasy',
#   8.7,
#   100.0,
#   150.0,
#   50.0,
#   'Spielberg',
#   'Actor C',
#   2020.0),
#  (103,
#   'Movie 103',
#   'Drama',
#   8.0,
#   60.0,
#   80.0,
#   20.0,
#   'Scorsese',
#   'Actor D',
#   2017.0),
#  (1030,
#   'Movie 1030',
#   'Romance',
#   8.6,
#   60.0,
#   20.0,
#   -40.0,
#   'Cameron',
#   'Actor C',
#   2015.0),
#  (1031,
#   'Movie 1031',
#   'Drama',
#   8.2,
#   100.0,
#   150.0,
#   50.0,
#   'Cameron',
#   'Actor C',
#   2022.0),
#  (1032,
#   'Movie 1032',
#   'Drama',
#   6.2,
#   60.0,
#   20.0,
#   -40.0,
#   'unknown',
#   'unknown',
#   2019.0),
#  (1033,
#   'Movie 1033',
#   'Thriller',
#   5.4,
#   30.0,
#   80.0,
#   50.0,
#   'unknown',
#   'Actor D',
#   2015.0),
#  (1034,
#   'Movie 1034',
#   'Romance',
#   6.1,
#   10.0,
#   600.0,
#   590.0,
#   'Rajamouli',
#   'Actor B',
#   2020.0),
#  (1035,
#   'Movie 1035',
#   'Fantasy',
#   8.3,
#   10.0,
#   150.0,
#   140.0,
#   'unknown',
#   'unknown',
#   2022.0),
#  (1036,
#   'Movie 1036',
#   'Horror',
#   6.6,
#   150.0,
#   300.0,
#   150.0,
#   'Nolan',
#   'Actor D',
#   2018.0),
#  (5504,
#   'Movie 1037',
#   'Fantasy',
#   5.1,
#   60.0,
#   300.0,
#   240.0,
#   'Nolan',
#   'unknown',
#   2015.0),
#  (1038,
#   'Movie 1038',
#   'Comedy',
#   9.0,
#   150.0,
#   150.0,
#   0.0,
#   'unknown',
#   'Actor D',
#   2019.0),
#  (1039,
#   'Movie 1039',
#   'Horror',
#   6.6,
#   30.0,
#   80.0,
#   50.0,
#   'Cameron',
#   'Actor B',
#   2015.0),
#  (104,
#   'Movie 104',
#   'Drama',
#   4.9,
#   100.0,
#   600.0,
#   500.0,
#   'Tarantino',
#   'unknown',
#   2018.0),
#  (1040,
#   'Movie 1040',
#   'Action',
#   5.0,
#   60.0,
#   600.0,
#   540.0,
#   'Cameron',
#   'Actor B',
#   2022.0),
#  (1041,
#   'Movie 1041',
#   'Romance',
#   4.4,
#   60.0,
#   300.0,
#   240.0,
#   'Scorsese',
#   'Actor C',
#   2022.0),
#  (1042,
#   'Movie 1042',
#   'Comedy',
#   4.5,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'Actor A',
#   2019.0),
#  (1043,
#   'Movie 1043',
#   'Romance',
#   4.5,
#   60.0,
#   80.0,
#   20.0,
#   'Tarantino',
#   'Actor B',
#   2016.0),
#  (1044,
#   'Movie 1044',
#   'Sci-Fi',
#   4.9,
#   150.0,
#   80.0,
#   -70.0,
#   'Rajamouli',
#   'Actor A',
#   2020.0),
#  (1045,
#   'Movie 1045',
#   'Drama',
#   6.5,
#   150.0,
#   20.0,
#   -130.0,
#   'Scorsese',
#   'unknown',
#   2018.0),
#  (1046,
#   'Movie 1046',
#   'Action',
#   7.5,
#   150.0,
#   80.0,
#   -70.0,
#   'Rajamouli',
#   'Actor E',
#   2022.0),
#  (1047,
#   'Movie 1047',
#   'Thriller',
#   8.1,
#   30.0,
#   300.0,
#   270.0,
#   'Spielberg',
#   'Actor D',
#   2018.0),
#  (1048,
#   'Movie 1048',
#   'Thriller',
#   3.8,
#   10.0,
#   300.0,
#   290.0,
#   'Nolan',
#   'Actor D',
#   2021.0),
#  (1049,
#   'Movie 1049',
#   'Romance',
#   7.8,
#   30.0,
#   20.0,
#   -10.0,
#   'Rajamouli',
#   'unknown',
#   2016.0),
#  (1050,
#   'Movie 1049',
#   'Thriller',
#   7.1,
#   60.0,
#   20.0,
#   -40.0,
#   'unknown',
#   'Actor D',
#   2020.0),
#  (105,
#   'Movie 105',
#   'Sci-Fi',
#   6.1,
#   60.0,
#   600.0,
#   540.0,
#   'Rajamouli',
#   'unknown',
#   2016.0),
#  (1051,
#   'Movie 1051',
#   'Thriller',
#   3.9,
#   100.0,
#   600.0,
#   500.0,
#   'Scorsese',
#   'Actor E',
#   2018.0),
#  (1052,
#   'Movie 1052',
#   'Action',
#   5.0,
#   10.0,
#   600.0,
#   590.0,
#   'Spielberg',
#   'Actor E',
#   2020.0),
#  (1053,
#   'Movie 1053',
#   'Romance',
#   8.0,
#   10.0,
#   80.0,
#   70.0,
#   'Tarantino',
#   'Actor D',
#   2020.0),
#  (5505,
#   'Movie 1054',
#   'Comedy',
#   5.3,
#   60.0,
#   80.0,
#   20.0,
#   'Scorsese',
#   'Actor E',
#   2018.0),
#  (1055,
#   'Movie 1055',
#   'Romance',
#   7.1,
#   30.0,
#   600.0,
#   570.0,
#   'Rajamouli',
#   'unknown',
#   2017.0),
#  (1056,
#   'Movie 1056',
#   'Comedy',
#   8.6,
#   60.0,
#   300.0,
#   240.0,
#   'Cameron',
#   'Actor A',
#   2015.0),
#  (1057,
#   'Movie 1057',
#   'Horror',
#   5.1,
#   150.0,
#   150.0,
#   0.0,
#   'Spielberg',
#   'Actor C',
#   2021.0),
#  (1058,
#   'Movie 1058',
#   'Drama',
#   8.9,
#   10.0,
#   300.0,
#   290.0,
#   'Scorsese',
#   'Actor B',
#   2019.0),
#  (1059,
#   'Movie 1059',
#   'Thriller',
#   7.0,
#   30.0,
#   150.0,
#   120.0,
#   'Spielberg',
#   'Actor E',
#   2019.0),
#  (106,
#   'Movie 106',
#   'Drama',
#   6.6,
#   100.0,
#   150.0,
#   50.0,
#   'unknown',
#   'Actor E',
#   2017.0),
#  (1060,
#   'Movie 1060',
#   'Horror',
#   6.4,
#   10.0,
#   80.0,
#   70.0,
#   'unknown',
#   'unknown',
#   2018.0),
#  (1061,
#   'Movie 1061',
#   'Drama',
#   7.5,
#   100.0,
#   300.0,
#   200.0,
#   'Scorsese',
#   'Actor C',
#   2020.0),
#  (1062,
#   'Movie 1062',
#   'Drama',
#   5.4,
#   150.0,
#   150.0,
#   0.0,
#   'Spielberg',
#   'Actor C',
#   2018.0),
#  (1063,
#   'Movie 1063',
#   'Thriller',
#   5.3,
#   100.0,
#   600.0,
#   500.0,
#   'Nolan',
#   'Actor D',
#   2018.0),
#  (1064,
#   'Movie 1064',
#   'Drama',
#   6.5,
#   30.0,
#   300.0,
#   270.0,
#   'Nolan',
#   'Actor B',
#   2019.0),
#  (1065,
#   'Movie 1065',
#   'Comedy',
#   8.0,
#   150.0,
#   600.0,
#   450.0,
#   'Cameron',
#   'unknown',
#   2016.0),
#  (1066,
#   'Movie 1066',
#   'Fantasy',
#   4.9,
#   60.0,
#   80.0,
#   20.0,
#   'Rajamouli',
#   'Actor A',
#   2016.0),
#  (1067,
#   'Movie 1067',
#   'Romance',
#   5.4,
#   100.0,
#   80.0,
#   -20.0,
#   'Spielberg',
#   'Actor C',
#   2021.0),
#  (1068,
#   'Movie 1068',
#   'Sci-Fi',
#   4.6,
#   10.0,
#   20.0,
#   10.0,
#   'Scorsese',
#   'Actor E',
#   2022.0),
#  (1069,
#   'Movie 1069',
#   'Thriller',
#   7.8,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'unknown',
#   2019.0),
#  (107,
#   'Movie 107',
#   'Drama',
#   3.8,
#   60.0,
#   20.0,
#   -40.0,
#   'Scorsese',
#   'Actor A',
#   2017.0),
#  (1070,
#   'Movie 1070',
#   'Romance',
#   4.9,
#   100.0,
#   600.0,
#   500.0,
#   'Scorsese',
#   'unknown',
#   2020.0),
#  (5506,
#   'Movie 1071',
#   'Romance',
#   9.2,
#   30.0,
#   600.0,
#   570.0,
#   'Rajamouli',
#   'Actor C',
#   2019.0),
#  (1072,
#   'Movie 1072',
#   'Thriller',
#   7.7,
#   150.0,
#   80.0,
#   -70.0,
#   'Spielberg',
#   'Actor C',
#   2019.0),
#  (1073,
#   'Movie 1073',
#   'Sci-Fi',
#   7.5,
#   150.0,
#   80.0,
#   -70.0,
#   'Spielberg',
#   'Actor D',
#   2021.0),
#  (1074,
#   'Movie 1074',
#   'Romance',
#   7.3,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor B',
#   2018.0),
#  (1075,
#   'Movie 1074',
#   'Comedy',
#   8.3,
#   60.0,
#   300.0,
#   240.0,
#   'Scorsese',
#   'Actor A',
#   2021.0),
#  (1076,
#   'Movie 1076',
#   'Thriller',
#   6.0,
#   10.0,
#   300.0,
#   290.0,
#   'Nolan',
#   'unknown',
#   2019.0),
#  (1077,
#   'Movie 1077',
#   'Action',
#   4.0,
#   30.0,
#   80.0,
#   50.0,
#   'Spielberg',
#   'Actor D',
#   2019.0),
#  (1078,
#   'Movie 1078',
#   'Action',
#   8.4,
#   30.0,
#   300.0,
#   270.0,
#   'Scorsese',
#   'Actor A',
#   2019.0),
#  (1079,
#   'Movie 1079',
#   'Horror',
#   8.9,
#   10.0,
#   300.0,
#   290.0,
#   'unknown',
#   'Actor A',
#   2017.0),
#  (108,
#   'Movie 108',
#   'Drama',
#   4.1,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'Actor D',
#   2017.0),
#  (1080,
#   'Movie 1080',
#   'Horror',
#   6.6,
#   10.0,
#   80.0,
#   70.0,
#   'Nolan',
#   'Actor B',
#   2017.0),
#  (1081,
#   'Movie 1081',
#   'Drama',
#   9.2,
#   10.0,
#   600.0,
#   590.0,
#   'Scorsese',
#   'unknown',
#   2018.0),
#  (1082,
#   'Movie 1082',
#   'Romance',
#   8.7,
#   150.0,
#   600.0,
#   450.0,
#   'Cameron',
#   'Actor C',
#   2016.0),
#  (1083,
#   'Movie 1083',
#   'Action',
#   6.6,
#   150.0,
#   150.0,
#   0.0,
#   'Nolan',
#   'Actor B',
#   2017.0),
#  (1084,
#   'Movie 1084',
#   'Romance',
#   4.0,
#   60.0,
#   300.0,
#   240.0,
#   'Tarantino',
#   'Actor A',
#   2022.0),
#  (1085,
#   'Movie 1085',
#   'Action',
#   5.7,
#   10.0,
#   600.0,
#   590.0,
#   'Cameron',
#   'Actor D',
#   2022.0),
#  (1086,
#   'Movie 1086',
#   'Comedy',
#   5.6,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'unknown',
#   2019.0),
#  (1087,
#   'Movie 1087',
#   'Fantasy',
#   8.2,
#   10.0,
#   300.0,
#   290.0,
#   'unknown',
#   'Actor A',
#   2019.0),
#  (5507,
#   'Movie 1088',
#   'Romance',
#   4.6,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor B',
#   2016.0),
#  (1089,
#   'Movie 1089',
#   'Thriller',
#   4.3,
#   30.0,
#   150.0,
#   120.0,
#   'Spielberg',
#   'unknown',
#   2019.0),
#  (109,
#   'Movie 109',
#   'Sci-Fi',
#   8.8,
#   10.0,
#   150.0,
#   140.0,
#   'Nolan',
#   'Actor B',
#   2018.0),
#  (1090,
#   'Movie 1090',
#   'Drama',
#   3.7,
#   30.0,
#   600.0,
#   570.0,
#   'Tarantino',
#   'Actor D',
#   2018.0),
#  (1091,
#   'Movie 1091',
#   'Romance',
#   5.6,
#   60.0,
#   80.0,
#   20.0,
#   'unknown',
#   'Actor C',
#   2015.0),
#  (1092,
#   'Movie 1092',
#   'Romance',
#   5.8,
#   150.0,
#   20.0,
#   -130.0,
#   'Cameron',
#   'Actor E',
#   2015.0),
#  (1093,
#   'Movie 1093',
#   'Romance',
#   8.3,
#   60.0,
#   80.0,
#   20.0,
#   'Tarantino',
#   'Actor C',
#   2022.0),
#  (1094,
#   'Movie 1094',
#   'Drama',
#   6.7,
#   100.0,
#   150.0,
#   50.0,
#   'unknown',
#   'unknown',
#   2015.0),
#  (1095,
#   'Movie 1095',
#   'Horror',
#   6.9,
#   60.0,
#   80.0,
#   20.0,
#   'Cameron',
#   'Actor A',
#   2016.0),
#  (1096,
#   'Movie 1096',
#   'Romance',
#   6.0,
#   30.0,
#   150.0,
#   120.0,
#   'Cameron',
#   'Actor D',
#   2018.0),
#  (1097,
#   'Movie 1097',
#   'Drama',
#   3.8,
#   60.0,
#   150.0,
#   90.0,
#   'Scorsese',
#   'Actor E',
#   2018.0),
#  (1098,
#   'Movie 1098',
#   'Thriller',
#   7.5,
#   60.0,
#   20.0,
#   -40.0,
#   'Cameron',
#   'Actor B',
#   2020.0),
#  (1100,
#   'Movie 1099',
#   'Romance',
#   5.3,
#   10.0,
#   300.0,
#   290.0,
#   'unknown',
#   'Actor D',
#   2016.0),
#  (1099,
#   'Movie 1099',
#   'Fantasy',
#   9.4,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor A',
#   2018.0),
#  (11,
#   'Movie 11',
#   'Thriller',
#   9.4,
#   60.0,
#   150.0,
#   90.0,
#   'Scorsese',
#   'Actor B',
#   2017.0),
#  (110,
#   'Movie 110',
#   'Comedy',
#   4.8,
#   60.0,
#   20.0,
#   -40.0,
#   'Rajamouli',
#   'Actor A',
#   2022.0),
#  (1101,
#   'Movie 1101',
#   'Horror',
#   5.4,
#   30.0,
#   80.0,
#   50.0,
#   'Cameron',
#   'Actor E',
#   2015.0),
#  (1102,
#   'Movie 1102',
#   'Action',
#   6.6,
#   60.0,
#   80.0,
#   20.0,
#   'Rajamouli',
#   'Actor D',
#   2021.0),
#  (1103,
#   'Movie 1103',
#   'Action',
#   6.8,
#   60.0,
#   150.0,
#   90.0,
#   'Rajamouli',
#   'unknown',
#   2019.0),
#  (1104,
#   'Movie 1104',
#   'Horror',
#   4.2,
#   150.0,
#   150.0,
#   0.0,
#   'Scorsese',
#   'Actor C',
#   2015.0),
#  (5508,
#   'Movie 1105',
#   'Fantasy',
#   7.3,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'Actor C',
#   2016.0),
#  (1106,
#   'Movie 1106',
#   'Drama',
#   7.2,
#   60.0,
#   600.0,
#   540.0,
#   'Rajamouli',
#   'Actor A',
#   2017.0),
#  (1107,
#   'Movie 1107',
#   'Romance',
#   9.0,
#   30.0,
#   150.0,
#   120.0,
#   'Rajamouli',
#   'Actor E',
#   2021.0),
#  (1108,
#   'Movie 1108',
#   'Fantasy',
#   4.7,
#   30.0,
#   150.0,
#   120.0,
#   'Rajamouli',
#   'Actor E',
#   2017.0),
#  (1109,
#   'Movie 1109',
#   'Sci-Fi',
#   4.1,
#   10.0,
#   150.0,
#   140.0,
#   'Cameron',
#   'Actor D',
#   2019.0),
#  (111,
#   'Movie 111',
#   'Drama',
#   9.3,
#   10.0,
#   20.0,
#   10.0,
#   'Rajamouli',
#   'Actor D',
#   2017.0),
#  (1110,
#   'Movie 1110',
#   'Fantasy',
#   3.9,
#   150.0,
#   150.0,
#   0.0,
#   'Rajamouli',
#   'unknown',
#   2021.0),
#  (1111,
#   'Movie 1111',
#   'Comedy',
#   8.1,
#   150.0,
#   80.0,
#   -70.0,
#   'Tarantino',
#   'Actor C',
#   2015.0),
#  (1112,
#   'Movie 1112',
#   'Drama',
#   6.9,
#   100.0,
#   150.0,
#   50.0,
#   'unknown',
#   'Actor B',
#   2016.0),
#  (1113,
#   'Movie 1113',
#   'Horror',
#   8.2,
#   30.0,
#   150.0,
#   120.0,
#   'Nolan',
#   'unknown',
#   2018.0),
#  (1114,
#   'Movie 1114',
#   'Thriller',
#   8.0,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'Actor E',
#   2018.0),
#  (1115,
#   'Movie 1115',
#   'Horror',
#   4.8,
#   30.0,
#   20.0,
#   -10.0,
#   'Nolan',
#   'Actor C',
#   2016.0),
#  (1116,
#   'Movie 1116',
#   'Action',
#   5.5,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'unknown',
#   2019.0),
#  (1117,
#   'Movie 1117',
#   'Romance',
#   9.0,
#   10.0,
#   300.0,
#   290.0,
#   'Cameron',
#   'unknown',
#   2018.0),
#  (1118,
#   'Movie 1118',
#   'Thriller',
#   4.2,
#   150.0,
#   80.0,
#   -70.0,
#   'Spielberg',
#   'Actor D',
#   2016.0),
#  (1119,
#   'Movie 1119',
#   'Horror',
#   4.2,
#   10.0,
#   600.0,
#   590.0,
#   'Spielberg',
#   'Actor A',
#   2017.0),
#  (112,
#   'Movie 112',
#   'Action',
#   8.5,
#   60.0,
#   300.0,
#   240.0,
#   'Rajamouli',
#   'unknown',
#   2020.0),
#  (1120,
#   'Movie 1120',
#   'Horror',
#   6.9,
#   100.0,
#   80.0,
#   -20.0,
#   'Cameron',
#   'unknown',
#   2019.0),
#  (1121,
#   'Movie 1121',
#   'Comedy',
#   6.5,
#   30.0,
#   20.0,
#   -10.0,
#   'Spielberg',
#   'Actor D',
#   2019.0),
#  (5509,
#   'Movie 1122',
#   'Drama',
#   5.0,
#   150.0,
#   600.0,
#   450.0,
#   'Nolan',
#   'Actor B',
#   2015.0),
#  (1123,
#   'Movie 1123',
#   'Sci-Fi',
#   5.9,
#   60.0,
#   80.0,
#   20.0,
#   'Tarantino',
#   'unknown',
#   2019.0),
#  (1125,
#   'Movie 1124',
#   'Fantasy',
#   8.5,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'unknown',
#   2022.0),
#  (1126,
#   'Movie 1126',
#   'Drama',
#   6.1,
#   30.0,
#   150.0,
#   120.0,
#   'Cameron',
#   'Actor E',
#   2017.0),
#  (1127,
#   'Movie 1127',
#   'Drama',
#   3.8,
#   10.0,
#   600.0,
#   590.0,
#   'Scorsese',
#   'Actor B',
#   2021.0),
#  (1128,
#   'Movie 1128',
#   'Action',
#   6.5,
#   10.0,
#   80.0,
#   70.0,
#   'Nolan',
#   'Actor D',
#   2018.0),
#  (1129,
#   'Movie 1129',
#   'Horror',
#   5.3,
#   100.0,
#   150.0,
#   50.0,
#   'Rajamouli',
#   'Actor C',
#   2015.0),
#  (113,
#   'Movie 113',
#   'Fantasy',
#   4.8,
#   60.0,
#   300.0,
#   240.0,
#   'Nolan',
#   'Actor B',
#   2022.0),
#  (1130,
#   'Movie 1130',
#   'Romance',
#   5.9,
#   10.0,
#   150.0,
#   140.0,
#   'Scorsese',
#   'Actor C',
#   2016.0),
#  (1131,
#   'Movie 1131',
#   'Thriller',
#   8.4,
#   30.0,
#   20.0,
#   -10.0,
#   'unknown',
#   'unknown',
#   2019.0),
#  (1132,
#   'Movie 1132',
#   'Romance',
#   5.0,
#   30.0,
#   150.0,
#   120.0,
#   'Rajamouli',
#   'Actor C',
#   2020.0),
#  (1133,
#   'Movie 1133',
#   'Fantasy',
#   6.8,
#   60.0,
#   300.0,
#   240.0,
#   'Spielberg',
#   'Actor B',
#   2022.0),
#  (1134,
#   'Movie 1134',
#   'Sci-Fi',
#   7.5,
#   30.0,
#   80.0,
#   50.0,
#   'Spielberg',
#   'Actor A',
#   2020.0),
#  (1135,
#   'Movie 1135',
#   'Comedy',
#   6.8,
#   30.0,
#   150.0,
#   120.0,
#   'Tarantino',
#   'Actor E',
#   2017.0),
#  (1136,
#   'Movie 1136',
#   'Horror',
#   8.5,
#   150.0,
#   150.0,
#   0.0,
#   'Scorsese',
#   'unknown',
#   2019.0),
#  (1137,
#   'Movie 1137',
#   'Sci-Fi',
#   5.5,
#   100.0,
#   600.0,
#   500.0,
#   'Cameron',
#   'Actor B',
#   2015.0),
#  (1138,
#   'Movie 1138',
#   'Sci-Fi',
#   6.0,
#   150.0,
#   300.0,
#   150.0,
#   'Nolan',
#   'Actor B',
#   2015.0),
#  (5510,
#   'Movie 1139',
#   'Thriller',
#   5.6,
#   60.0,
#   80.0,
#   20.0,
#   'Rajamouli',
#   'Actor E',
#   2018.0),
#  (114,
#   'Movie 114',
#   'Horror',
#   6.4,
#   30.0,
#   150.0,
#   120.0,
#   'Tarantino',
#   'Actor A',
#   2016.0),
#  (1140,
#   'Movie 1140',
#   'Sci-Fi',
#   6.6,
#   30.0,
#   150.0,
#   120.0,
#   'Scorsese',
#   'Actor E',
#   2019.0),
#  (1141,
#   'Movie 1141',
#   'Drama',
#   4.9,
#   100.0,
#   150.0,
#   50.0,
#   'Rajamouli',
#   'Actor D',
#   2015.0),
#  (1142,
#   'Movie 1142',
#   'Thriller',
#   4.1,
#   100.0,
#   300.0,
#   200.0,
#   'Cameron',
#   'Actor E',
#   2021.0),
#  (1143,
#   'Movie 1143',
#   'Thriller',
#   7.6,
#   60.0,
#   300.0,
#   240.0,
#   'Tarantino',
#   'Actor D',
#   2019.0),
#  (1144,
#   'Movie 1144',
#   'Romance',
#   8.6,
#   10.0,
#   150.0,
#   140.0,
#   'unknown',
#   'Actor E',
#   2020.0),
#  (1145,
#   'Movie 1145',
#   'Thriller',
#   6.5,
#   30.0,
#   150.0,
#   120.0,
#   'Cameron',
#   'Actor E',
#   2017.0),
#  (1146,
#   'Movie 1146',
#   'Fantasy',
#   8.3,
#   60.0,
#   150.0,
#   90.0,
#   'Rajamouli',
#   'Actor A',
#   2018.0),
#  (1147,
#   'Movie 1147',
#   'Drama',
#   7.0,
#   100.0,
#   150.0,
#   50.0,
#   'unknown',
#   'Actor A',
#   2021.0),
#  (1148,
#   'Movie 1148',
#   'Fantasy',
#   8.3,
#   30.0,
#   150.0,
#   120.0,
#   'Spielberg',
#   'Actor D',
#   2018.0),
#  (1150,
#   'Movie 1149',
#   'Comedy',
#   5.6,
#   100.0,
#   150.0,
#   50.0,
#   'Tarantino',
#   'unknown',
#   2015.0),
#  (1149,
#   'Movie 1149',
#   'Romance',
#   7.6,
#   30.0,
#   300.0,
#   270.0,
#   'Nolan',
#   'Actor D',
#   2018.0),
#  (115,
#   'Movie 115',
#   'Action',
#   4.8,
#   100.0,
#   300.0,
#   200.0,
#   'Rajamouli',
#   'Actor D',
#   2021.0),
#  (1151,
#   'Movie 1151',
#   'Romance',
#   7.7,
#   30.0,
#   150.0,
#   120.0,
#   'Scorsese',
#   'Actor A',
#   2016.0),
#  (1152,
#   'Movie 1152',
#   'Thriller',
#   5.7,
#   60.0,
#   150.0,
#   90.0,
#   'Spielberg',
#   'Actor D',
#   2019.0),
#  (1153,
#   'Movie 1153',
#   'Horror',
#   6.9,
#   60.0,
#   20.0,
#   -40.0,
#   'unknown',
#   'Actor C',
#   2018.0),
#  (1154,
#   'Movie 1154',
#   'Fantasy',
#   3.6,
#   30.0,
#   20.0,
#   -10.0,
#   'unknown',
#   'Actor C',
#   2018.0),
#  (1155,
#   'Movie 1155',
#   'Comedy',
#   3.6,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor E',
#   2016.0),
#  (5511,
#   'Movie 1156',
#   'Sci-Fi',
#   6.9,
#   30.0,
#   150.0,
#   120.0,
#   'Rajamouli',
#   'Actor E',
#   2016.0),
#  (1157,
#   'Movie 1157',
#   'Fantasy',
#   4.7,
#   60.0,
#   600.0,
#   540.0,
#   'Rajamouli',
#   'Actor D',
#   2021.0),
#  (1158,
#   'Movie 1158',
#   'Action',
#   8.5,
#   60.0,
#   150.0,
#   90.0,
#   'Spielberg',
#   'unknown',
#   2019.0),
#  (1159,
#   'Movie 1159',
#   'Action',
#   6.6,
#   30.0,
#   80.0,
#   50.0,
#   'Tarantino',
#   'Actor B',
#   2016.0),
#  (116,
#   'Movie 116',
#   'Sci-Fi',
#   3.9,
#   30.0,
#   150.0,
#   120.0,
#   'unknown',
#   'Actor A',
#   2017.0),
#  (1160,
#   'Movie 1160',
#   'Horror',
#   6.7,
#   30.0,
#   80.0,
#   50.0,
#   'Cameron',
#   'Actor B',
#   2019.0),
#  (1161,
#   'Movie 1161',
#   'Romance',
#   7.9,
#   60.0,
#   20.0,
#   -40.0,
#   'Spielberg',
#   'Actor D',
#   2022.0),
#  (1162,
#   'Movie 1162',
#   'Action',
#   8.0,
#   60.0,
#   80.0,
#   20.0,
#   'Scorsese',
#   'Actor B',
#   2015.0),
#  (1163,
#   'Movie 1163',
#   'Horror',
#   5.1,
#   100.0,
#   150.0,
#   50.0,
#   'Spielberg',
#   'Actor E',
#   2018.0),
#  (1164,
#   'Movie 1164',
#   'Thriller',
#   8.7,
#   150.0,
#   80.0,
#   -70.0,
#   'Tarantino',
#   'Actor E',
#   2016.0),
#  (1165,
#   'Movie 1165',
#   'Fantasy',
#   5.6,
#   10.0,
#   300.0,
#   290.0,
#   'unknown',
#   'Actor B',
#   2018.0),
#  (1166,
#   'Movie 1166',
#   'Horror',
#   4.6,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'Actor A',
#   2018.0),
#  (1167,
#   'Movie 1167',
#   'Horror',
#   5.2,
#   150.0,
#   600.0,
#   450.0,
#   'Nolan',
#   'Actor C',
#   2016.0),
#  (1168,
#   'Movie 1168',
#   'Sci-Fi',
#   9.1,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor B',
#   2018.0),
#  (1169,
#   'Movie 1169',
#   'Horror',
#   3.6,
#   150.0,
#   80.0,
#   -70.0,
#   'Tarantino',
#   'Actor C',
#   2016.0),
#  (117,
#   'Movie 117',
#   'Comedy',
#   9.2,
#   60.0,
#   80.0,
#   20.0,
#   'Spielberg',
#   'unknown',
#   2019.0),
#  (1170,
#   'Movie 1170',
#   'Romance',
#   3.6,
#   60.0,
#   600.0,
#   540.0,
#   'Scorsese',
#   'unknown',
#   2022.0),
#  (1171,
#   'Movie 1171',
#   'Sci-Fi',
#   8.6,
#   10.0,
#   150.0,
#   140.0,
#   'unknown',
#   'Actor C',
#   2017.0),
#  (1172,
#   'Movie 1172',
#   'Sci-Fi',
#   3.5,
#   60.0,
#   80.0,
#   20.0,
#   'Scorsese',
#   'Actor E',
#   2022.0),
#  (5512,
#   'Movie 1173',
#   'Action',
#   3.9,
#   100.0,
#   600.0,
#   500.0,
#   'Scorsese',
#   'unknown',
#   2015.0),
#  (1175,
#   'Movie 1174',
#   'Horror',
#   6.8,
#   30.0,
#   600.0,
#   570.0,
#   'Tarantino',
#   'Actor C',
#   2015.0),
#  (1174,
#   'Movie 1174',
#   'Drama',
#   9.3,
#   60.0,
#   80.0,
#   20.0,
#   'Nolan',
#   'Actor D',
#   2020.0),
#  (1176,
#   'Movie 1176',
#   'Romance',
#   4.2,
#   150.0,
#   150.0,
#   0.0,
#   'Rajamouli',
#   'unknown',
#   2015.0),
#  (1177,
#   'Movie 1177',
#   'Comedy',
#   6.9,
#   10.0,
#   300.0,
#   290.0,
#   'Rajamouli',
#   'Actor B',
#   2018.0),
#  (1178,
#   'Movie 1178',
#   'Comedy',
#   6.5,
#   150.0,
#   150.0,
#   0.0,
#   'Cameron',
#   'Actor E',
#   2021.0),
#  (1179,
#   'Movie 1179',
#   'Thriller',
#   6.7,
#   10.0,
#   300.0,
#   290.0,
#   'Scorsese',
#   'Actor D',
#   2015.0),
#  (118,
#   'Movie 118',
#   'Sci-Fi',
#   5.8,
#   60.0,
#   20.0,
#   -40.0,
#   'Tarantino',
#   'Actor C',
#   2016.0),
#  (1180,
#   'Movie 1180',
#   'Thriller',
#   8.5,
#   60.0,
#   150.0,
#   90.0,
#   'Spielberg',
#   'Actor C',
#   2017.0),
#  (1181,
#   'Movie 1181',
#   'Action',
#   8.0,
#   10.0,
#   300.0,
#   290.0,
#   'Tarantino',
#   'Actor A',
#   2018.0),
#  (1182,
#   'Movie 1182',
#   'Romance',
#   9.2,
#   60.0,
#   600.0,
#   540.0,
#   'Rajamouli',
#   'Actor C',
#   2018.0),
#  (1183,
#   'Movie 1183',
#   'Sci-Fi',
#   6.9,
#   150.0,
#   300.0,
#   150.0,
#   'Rajamouli',
#   'Actor C',
#   2019.0),
#  (1184,
#   'Movie 1184',
#   'Horror',
#   9.3,
#   60.0,
#   20.0,
#   -40.0,
#   'Cameron',
#   'Actor A',
#   2018.0),
#  (1185,
#   'Movie 1185',
#   'Thriller',
#   7.4,
#   60.0,
#   20.0,
#   -40.0,
#   'Cameron',
#   'Actor D',
#   2015.0),
#  (1186,
#   'Movie 1186',
#   'Horror',
#   4.4,
#   100.0,
#   80.0,
#   -20.0,
#   'Spielberg',
#   'Actor A',
#   2018.0),
#  (1187,
#   'Movie 1187',
#   'Comedy',
#   8.6,
#   60.0,
#   300.0,
#   240.0,
#   'Scorsese',
#   'Actor B',
#   2020.0),
#  (1188,
#   'Movie 1188',
#   'Drama',
#   8.8,
#   60.0,
#   150.0,
#   90.0,
#   'Spielberg',
#   'Actor C',
#   2017.0),
#  (1189,
#   'Movie 1189',
#   'Sci-Fi',
#   3.7,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'Actor E',
#   2017.0),
#  (5513,
#   'Movie 119',
#   'Action',
#   8.6,
#   150.0,
#   150.0,
#   0.0,
#   'Tarantino',
#   'unknown',
#   2017.0),
#  (5514,
#   'Movie 1190',
#   'Action',
#   9.5,
#   100.0,
#   20.0,
#   -80.0,
#   'Rajamouli',
#   'Actor A',
#   2019.0),
#  (1191,
#   'Movie 1191',
#   'Sci-Fi',
#   8.9,
#   30.0,
#   600.0,
#   570.0,
#   'unknown',
#   'Actor D',
#   2018.0),
#  (1192,
#   'Movie 1192',
#   'Sci-Fi',
#   8.8,
#   60.0,
#   150.0,
#   90.0,
#   'Rajamouli',
#   'Actor E',
#   2020.0),
#  (1193,
#   'Movie 1193',
#   'Fantasy',
#   3.6,
#   30.0,
#   20.0,
#   -10.0,
#   'Scorsese',
#   'Actor C',
#   2017.0),
#  (1194,
#   'Movie 1194',
#   'Romance',
#   3.9,
#   150.0,
#   150.0,
#   0.0,
#   'Scorsese',
#   'Actor D',
#   2021.0),
#  (1195,
#   'Movie 1195',
#   'Fantasy',
#   7.5,
#   100.0,
#   20.0,
#   -80.0,
#   'unknown',
#   'Actor C',
#   2021.0),
#  (1196,
#   'Movie 1196',
#   'Fantasy',
#   7.6,
#   100.0,
#   300.0,
#   200.0,
#   'Nolan',
#   'Actor B',
#   2018.0),
#  (1197,
#   'Movie 1197',
#   'Romance',
#   6.5,
#   10.0,
#   600.0,
#   590.0,
#   'Scorsese',
#   'Actor B',
#   2018.0),
#  (1198,
#   'Movie 1198',
#   'Sci-Fi',
#   6.7,
#   10.0,
#   20.0,
#   10.0,
#   'unknown',
#   'Actor C',
#   2021.0),
#  (1200,
#   'Movie 1199',
#   'Sci-Fi',
#   7.0,
#   100.0,
#   600.0,
#   500.0,
#   'unknown',
#   'Actor D',
#   2018.0),
#  (1199,
#   'Movie 1199',
#   'Drama',
#   5.5,
#   60.0,
#   20.0,
#   -40.0,
#   'Spielberg',
#   'Actor D',
#   2020.0),
#  (12,
#   'Movie 12',
#   'Comedy',
#   7.9,
#   60.0,
#   80.0,
#   20.0,
#   'unknown',
#   'Actor A',
#   2018.0),
#  (120,
#   'Movie 120',
#   'Horror',
#   3.8,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor D',
#   2017.0),
#  (1201,
#   'Movie 1201',
#   'Action',
#   8.6,
#   60.0,
#   600.0,
#   540.0,
#   'unknown',
#   'Actor C',
#   2016.0),
#  (1202,
#   'Movie 1202',
#   'Thriller',
#   9.3,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'Actor B',
#   2016.0),
#  (1203,
#   'Movie 1203',
#   'Fantasy',
#   6.3,
#   150.0,
#   600.0,
#   450.0,
#   'unknown',
#   'unknown',
#   2016.0),
#  (1204,
#   'Movie 1204',
#   'Action',
#   8.8,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'Actor D',
#   2022.0),
#  (1205,
#   'Movie 1205',
#   'Thriller',
#   5.4,
#   30.0,
#   80.0,
#   50.0,
#   'Tarantino',
#   'Actor B',
#   2021.0),
#  (1206,
#   'Movie 1206',
#   'Sci-Fi',
#   8.6,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'Actor A',
#   2015.0),
#  (5515,
#   'Movie 1207',
#   'Drama',
#   5.8,
#   150.0,
#   300.0,
#   150.0,
#   'Spielberg',
#   'Actor C',
#   2021.0),
#  (1208,
#   'Movie 1208',
#   'Sci-Fi',
#   7.4,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'Actor A',
#   2021.0),
#  (1209,
#   'Movie 1209',
#   'Horror',
#   4.3,
#   60.0,
#   300.0,
#   240.0,
#   'Spielberg',
#   'Actor C',
#   2018.0),
#  (121,
#   'Movie 121',
#   'Action',
#   7.0,
#   60.0,
#   20.0,
#   -40.0,
#   'unknown',
#   'Actor A',
#   2015.0),
#  (1210,
#   'Movie 1210',
#   'Comedy',
#   8.2,
#   150.0,
#   300.0,
#   150.0,
#   'Spielberg',
#   'Actor D',
#   2019.0),
#  (1211,
#   'Movie 1211',
#   'Comedy',
#   7.4,
#   10.0,
#   20.0,
#   10.0,
#   'Rajamouli',
#   'Actor C',
#   2015.0),
#  (1212,
#   'Movie 1212',
#   'Fantasy',
#   5.9,
#   30.0,
#   20.0,
#   -10.0,
#   'Cameron',
#   'Actor C',
#   2019.0),
#  (1213,
#   'Movie 1213',
#   'Sci-Fi',
#   8.4,
#   10.0,
#   150.0,
#   140.0,
#   'Tarantino',
#   'Actor C',
#   2016.0),
#  (1214,
#   'Movie 1214',
#   'Fantasy',
#   5.7,
#   30.0,
#   20.0,
#   -10.0,
#   'Cameron',
#   'Actor E',
#   2018.0),
#  (1215,
#   'Movie 1215',
#   'Thriller',
#   7.3,
#   30.0,
#   600.0,
#   570.0,
#   'Cameron',
#   'Actor E',
#   2019.0),
#  (1216,
#   'Movie 1216',
#   'Thriller',
#   6.5,
#   10.0,
#   150.0,
#   140.0,
#   'Tarantino',
#   'Actor E',
#   2018.0),
#  (1217,
#   'Movie 1217',
#   'Romance',
#   6.2,
#   100.0,
#   20.0,
#   -80.0,
#   'unknown',
#   'Actor A',
#   2022.0),
#  (1218,
#   'Movie 1218',
#   'Fantasy',
#   5.1,
#   10.0,
#   20.0,
#   10.0,
#   'Rajamouli',
#   'Actor E',
#   2020.0),
#  (1219,
#   'Movie 1219',
#   'Action',
#   6.4,
#   30.0,
#   20.0,
#   -10.0,
#   'unknown',
#   'Actor C',
#   2016.0),
#  (122,
#   'Movie 122',
#   'Sci-Fi',
#   7.1,
#   30.0,
#   150.0,
#   120.0,
#   'unknown',
#   'unknown',
#   2018.0),
#  (1220,
#   'Movie 1220',
#   'Drama',
#   4.4,
#   100.0,
#   20.0,
#   -80.0,
#   'Tarantino',
#   'Actor C',
#   2019.0),
#  (1221,
#   'Movie 1221',
#   'Action',
#   6.5,
#   100.0,
#   150.0,
#   50.0,
#   'Tarantino',
#   'Actor A',
#   2019.0),
#  (1222,
#   'Movie 1222',
#   'Thriller',
#   5.4,
#   10.0,
#   150.0,
#   140.0,
#   'Scorsese',
#   'Actor D',
#   2019.0),
#  (1223,
#   'Movie 1223',
#   'Romance',
#   3.7,
#   60.0,
#   300.0,
#   240.0,
#   'Cameron',
#   'Actor B',
#   2019.0),
#  (1225,
#   'Movie 1224',
#   'Sci-Fi',
#   5.3,
#   150.0,
#   150.0,
#   0.0,
#   'unknown',
#   'Actor C',
#   2016.0),
#  (5516,
#   'Movie 1224',
#   'Thriller',
#   6.1,
#   60.0,
#   300.0,
#   240.0,
#   'Tarantino',
#   'Actor B',
#   2021.0),
#  (1226,
#   'Movie 1226',
#   'Drama',
#   5.2,
#   150.0,
#   80.0,
#   -70.0,
#   'Rajamouli',
#   'unknown',
#   2018.0),
#  (1227,
#   'Movie 1227',
#   'Action',
#   4.3,
#   60.0,
#   80.0,
#   20.0,
#   'Rajamouli',
#   'Actor B',
#   2017.0),
#  (1228,
#   'Movie 1228',
#   'Romance',
#   6.0,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'Actor D',
#   2017.0),
#  (1229,
#   'Movie 1229',
#   'Romance',
#   6.5,
#   150.0,
#   80.0,
#   -70.0,
#   'Nolan',
#   'Actor E',
#   2022.0),
#  (123,
#   'Movie 123',
#   'Horror',
#   7.5,
#   10.0,
#   600.0,
#   590.0,
#   'Nolan',
#   'Actor E',
#   2021.0),
#  (1230,
#   'Movie 1230',
#   'Action',
#   8.2,
#   60.0,
#   20.0,
#   -40.0,
#   'unknown',
#   'Actor A',
#   2018.0),
#  (1231,
#   'Movie 1231',
#   'Romance',
#   9.3,
#   30.0,
#   600.0,
#   570.0,
#   'Spielberg',
#   'Actor D',
#   2022.0),
#  (1232,
#   'Movie 1232',
#   'Sci-Fi',
#   5.6,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'unknown',
#   2018.0),
#  (1233,
#   'Movie 1233',
#   'Horror',
#   7.6,
#   150.0,
#   150.0,
#   0.0,
#   'Scorsese',
#   'unknown',
#   2018.0),
#  (1234,
#   'Movie 1234',
#   'Romance',
#   6.6,
#   30.0,
#   80.0,
#   50.0,
#   'Tarantino',
#   'Actor A',
#   2018.0),
#  (1235,
#   'Movie 1235',
#   'Drama',
#   6.5,
#   60.0,
#   300.0,
#   240.0,
#   'Tarantino',
#   'Actor E',
#   2018.0),
#  (1236,
#   'Movie 1236',
#   'Comedy',
#   3.6,
#   150.0,
#   20.0,
#   -130.0,
#   'unknown',
#   'Actor B',
#   2017.0),
#  (1237,
#   'Movie 1237',
#   'Thriller',
#   8.9,
#   10.0,
#   80.0,
#   70.0,
#   'Nolan',
#   'Actor E',
#   2016.0),
#  (1238,
#   'Movie 1238',
#   'Romance',
#   4.3,
#   150.0,
#   80.0,
#   -70.0,
#   'Tarantino',
#   'Actor A',
#   2015.0),
#  (1239,
#   'Movie 1239',
#   'Sci-Fi',
#   5.3,
#   60.0,
#   600.0,
#   540.0,
#   'Scorsese',
#   'Actor D',
#   2022.0),
#  (124,
#   'Movie 124',
#   'Drama',
#   7.0,
#   100.0,
#   20.0,
#   -80.0,
#   'unknown',
#   'Actor D',
#   2015.0),
#  (125,
#   'Movie 124',
#   'Sci-Fi',
#   8.5,
#   60.0,
#   20.0,
#   -40.0,
#   'Nolan',
#   'Actor A',
#   2018.0),
#  (1240,
#   'Movie 1240',
#   'Romance',
#   4.2,
#   60.0,
#   20.0,
#   -40.0,
#   'Spielberg',
#   'Actor E',
#   2019.0),
#  (5517,
#   'Movie 1241',
#   'Drama',
#   7.6,
#   150.0,
#   600.0,
#   450.0,
#   'Tarantino',
#   'Actor B',
#   2017.0),
#  (1242,
#   'Movie 1242',
#   'Drama',
#   4.9,
#   60.0,
#   600.0,
#   540.0,
#   'Rajamouli',
#   'unknown',
#   2017.0),
#  (1243,
#   'Movie 1243',
#   'Fantasy',
#   8.9,
#   30.0,
#   150.0,
#   120.0,
#   'Scorsese',
#   'Actor E',
#   2017.0),
#  (1244,
#   'Movie 1244',
#   'Thriller',
#   3.9,
#   100.0,
#   20.0,
#   -80.0,
#   'Tarantino',
#   'Actor C',
#   2019.0),
#  (1245,
#   'Movie 1245',
#   'Action',
#   6.0,
#   60.0,
#   600.0,
#   540.0,
#   'Nolan',
#   'Actor D',
#   2015.0),
#  (1246,
#   'Movie 1246',
#   'Fantasy',
#   6.2,
#   10.0,
#   150.0,
#   140.0,
#   'Scorsese',
#   'Actor E',
#   2016.0),
#  (1247,
#   'Movie 1247',
#   'Action',
#   9.3,
#   60.0,
#   20.0,
#   -40.0,
#   'Rajamouli',
#   'Actor B',
#   2018.0),
#  (1248,
#   'Movie 1248',
#   'Comedy',
#   7.8,
#   60.0,
#   150.0,
#   90.0,
#   'Rajamouli',
#   'Actor C',
#   2018.0),
#  (1249,
#   'Movie 1249',
#   'Sci-Fi',
#   4.1,
#   150.0,
#   300.0,
#   150.0,
#   'Nolan',
#   'Actor D',
#   2021.0),
#  (1250,
#   'Movie 1249',
#   'Thriller',
#   8.2,
#   30.0,
#   150.0,
#   120.0,
#   'Nolan',
#   'Actor E',
#   2022.0),
#  (1251,
#   'Movie 1251',
#   'Comedy',
#   6.2,
#   60.0,
#   20.0,
#   -40.0,
#   'Tarantino',
#   'Actor E',
#   2019.0),
#  (1252,
#   'Movie 1252',
#   'Romance',
#   6.9,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor B',
#   2016.0),
#  (1253,
#   'Movie 1253',
#   'Action',
#   5.0,
#   150.0,
#   600.0,
#   450.0,
#   'Tarantino',
#   'Actor C',
#   2019.0),
#  (1254,
#   'Movie 1254',
#   'Horror',
#   6.4,
#   10.0,
#   150.0,
#   140.0,
#   'Spielberg',
#   'Actor D',
#   2021.0),
#  (1255,
#   'Movie 1255',
#   'Romance',
#   7.4,
#   60.0,
#   600.0,
#   540.0,
#   'Scorsese',
#   'Actor D',
#   2018.0),
#  (1256,
#   'Movie 1256',
#   'Fantasy',
#   6.8,
#   100.0,
#   150.0,
#   50.0,
#   'Spielberg',
#   'Actor E',
#   2015.0),
#  (1257,
#   'Movie 1257',
#   'Drama',
#   8.1,
#   100.0,
#   300.0,
#   200.0,
#   'Scorsese',
#   'Actor A',
#   2019.0),
#  (5518,
#   'Movie 1258',
#   'Comedy',
#   4.1,
#   150.0,
#   20.0,
#   -130.0,
#   'Spielberg',
#   'Actor C',
#   2022.0),
#  (1259,
#   'Movie 1259',
#   'Comedy',
#   9.0,
#   10.0,
#   300.0,
#   290.0,
#   'Scorsese',
#   'Actor B',
#   2015.0),
#  (126,
#   'Movie 126',
#   'Action',
#   9.3,
#   60.0,
#   600.0,
#   540.0,
#   'Spielberg',
#   'unknown',
#   2020.0),
#  (1260,
#   'Movie 1260',
#   'Drama',
#   5.0,
#   100.0,
#   600.0,
#   500.0,
#   'unknown',
#   'Actor A',
#   2016.0),
#  (1261,
#   'Movie 1261',
#   'Fantasy',
#   6.0,
#   100.0,
#   150.0,
#   50.0,
#   'Rajamouli',
#   'Actor C',
#   2022.0),
#  (1262,
#   'Movie 1262',
#   'Horror',
#   7.9,
#   100.0,
#   300.0,
#   200.0,
#   'Scorsese',
#   'Actor C',
#   2020.0),
#  (1263,
#   'Movie 1263',
#   'Fantasy',
#   7.6,
#   30.0,
#   150.0,
#   120.0,
#   'Cameron',
#   'unknown',
#   2020.0),
#  (1264,
#   'Movie 1264',
#   'Sci-Fi',
#   5.8,
#   10.0,
#   80.0,
#   70.0,
#   'Tarantino',
#   'Actor E',
#   2016.0),
#  (1265,
#   'Movie 1265',
#   'Comedy',
#   5.1,
#   10.0,
#   300.0,
#   290.0,
#   'Cameron',
#   'Actor C',
#   2018.0),
#  (1266,
#   'Movie 1266',
#   'Romance',
#   3.7,
#   100.0,
#   150.0,
#   50.0,
#   'Nolan',
#   'Actor A',
#   2015.0),
#  (1267,
#   'Movie 1267',
#   'Fantasy',
#   9.3,
#   30.0,
#   150.0,
#   120.0,
#   'Spielberg',
#   'Actor C',
#   2016.0),
#  (1268,
#   'Movie 1268',
#   'Comedy',
#   6.2,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'Actor E',
#   2016.0),
#  (1269,
#   'Movie 1269',
#   'Action',
#   9.1,
#   30.0,
#   300.0,
#   270.0,
#   'Nolan',
#   'Actor B',
#   2020.0),
#  (127,
#   'Movie 127',
#   'Horror',
#   5.7,
#   60.0,
#   80.0,
#   20.0,
#   'Cameron',
#   'Actor D',
#   2021.0),
#  (1270,
#   'Movie 1270',
#   'Drama',
#   6.6,
#   30.0,
#   300.0,
#   270.0,
#   'Rajamouli',
#   'Actor C',
#   2022.0),
#  (1271,
#   'Movie 1271',
#   'Comedy',
#   8.8,
#   10.0,
#   20.0,
#   10.0,
#   'Cameron',
#   'Actor E',
#   2019.0),
#  (1272,
#   'Movie 1272',
#   'Romance',
#   6.8,
#   60.0,
#   80.0,
#   20.0,
#   'Scorsese',
#   'unknown',
#   2017.0),
#  (1273,
#   'Movie 1273',
#   'Comedy',
#   6.5,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'Actor A',
#   2022.0),
#  (5519,
#   'Movie 1274',
#   'Drama',
#   6.9,
#   150.0,
#   300.0,
#   150.0,
#   'Spielberg',
#   'Actor E',
#   2016.0),
#  (1274,
#   'Movie 1274',
#   'Action',
#   4.8,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'Actor E',
#   2020.0),
#  (1276,
#   'Movie 1276',
#   'Thriller',
#   9.0,
#   150.0,
#   150.0,
#   0.0,
#   'Tarantino',
#   'unknown',
#   2015.0),
#  (1277,
#   'Movie 1277',
#   'Drama',
#   4.6,
#   10.0,
#   150.0,
#   140.0,
#   'Tarantino',
#   'Actor A',
#   2021.0),
#  (1278,
#   'Movie 1278',
#   'Fantasy',
#   6.2,
#   60.0,
#   300.0,
#   240.0,
#   'Rajamouli',
#   'Actor A',
#   2021.0),
#  (1279,
#   'Movie 1279',
#   'Fantasy',
#   7.5,
#   10.0,
#   80.0,
#   70.0,
#   'Tarantino',
#   'Actor D',
#   2022.0),
#  (128,
#   'Movie 128',
#   'Thriller',
#   5.6,
#   60.0,
#   20.0,
#   -40.0,
#   'Rajamouli',
#   'Actor A',
#   2015.0),
#  (1280,
#   'Movie 1280',
#   'Drama',
#   6.3,
#   30.0,
#   300.0,
#   270.0,
#   'Tarantino',
#   'Actor D',
#   2021.0),
#  (1281,
#   'Movie 1281',
#   'Fantasy',
#   5.8,
#   150.0,
#   150.0,
#   0.0,
#   'Cameron',
#   'Actor C',
#   2016.0),
#  (1282,
#   'Movie 1282',
#   'Horror',
#   4.7,
#   60.0,
#   600.0,
#   540.0,
#   'Rajamouli',
#   'Actor D',
#   2017.0),
#  (1283,
#   'Movie 1283',
#   'Action',
#   7.6,
#   30.0,
#   300.0,
#   270.0,
#   'unknown',
#   'unknown',
#   2019.0),
#  (1284,
#   'Movie 1284',
#   'Horror',
#   4.0,
#   30.0,
#   20.0,
#   -10.0,
#   'Cameron',
#   'Actor E',
#   2016.0),
#  (1285,
#   'Movie 1285',
#   'Romance',
#   6.1,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'unknown',
#   2016.0),
#  (1286,
#   'Movie 1286',
#   'Sci-Fi',
#   8.7,
#   100.0,
#   80.0,
#   -20.0,
#   'Spielberg',
#   'Actor C',
#   2017.0),
#  (1287,
#   'Movie 1287',
#   'Action',
#   4.3,
#   100.0,
#   600.0,
#   500.0,
#   'unknown',
#   'unknown',
#   2018.0),
#  (1288,
#   'Movie 1288',
#   'Action',
#   7.7,
#   30.0,
#   20.0,
#   -10.0,
#   'Rajamouli',
#   'Actor B',
#   2015.0),
#  (1289,
#   'Movie 1289',
#   'Sci-Fi',
#   7.9,
#   100.0,
#   600.0,
#   500.0,
#   'Cameron',
#   'unknown',
#   2017.0),
#  (129,
#   'Movie 129',
#   'Horror',
#   8.4,
#   30.0,
#   300.0,
#   270.0,
#   'Nolan',
#   'Actor B',
#   2019.0),
#  (1290,
#   'Movie 1290',
#   'Fantasy',
#   9.5,
#   60.0,
#   300.0,
#   240.0,
#   'Cameron',
#   'Actor D',
#   2018.0),
#  (1291,
#   'Movie 1291',
#   'Drama',
#   4.0,
#   100.0,
#   300.0,
#   200.0,
#   'Rajamouli',
#   'Actor E',
#   2017.0),
#  (5520,
#   'Movie 1292',
#   'Romance',
#   6.5,
#   30.0,
#   150.0,
#   120.0,
#   'Tarantino',
#   'Actor B',
#   2020.0),
#  (1293,
#   'Movie 1293',
#   'Romance',
#   6.7,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor C',
#   2017.0),
#  (1294,
#   'Movie 1294',
#   'Sci-Fi',
#   7.5,
#   150.0,
#   20.0,
#   -130.0,
#   'unknown',
#   'Actor E',
#   2017.0),
#  (1295,
#   'Movie 1295',
#   'Comedy',
#   8.8,
#   60.0,
#   600.0,
#   540.0,
#   'Cameron',
#   'Actor A',
#   2018.0),
#  (1296,
#   'Movie 1296',
#   'Action',
#   3.8,
#   60.0,
#   300.0,
#   240.0,
#   'Cameron',
#   'Actor D',
#   2017.0),
#  (1297,
#   'Movie 1297',
#   'Drama',
#   7.5,
#   100.0,
#   600.0,
#   500.0,
#   'unknown',
#   'unknown',
#   2015.0),
#  (1298,
#   'Movie 1298',
#   'Thriller',
#   9.1,
#   60.0,
#   300.0,
#   240.0,
#   'Spielberg',
#   'Actor A',
#   2019.0),
#  (1299,
#   'Movie 1299',
#   'Horror',
#   4.7,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'unknown',
#   2019.0),
#  (1300,
#   'Movie 1299',
#   'Thriller',
#   5.5,
#   60.0,
#   600.0,
#   540.0,
#   'Rajamouli',
#   'unknown',
#   2022.0),
#  (13,
#   'Movie 13',
#   'Thriller',
#   5.8,
#   60.0,
#   20.0,
#   -40.0,
#   'unknown',
#   'Actor D',
#   2015.0),
#  (130,
#   'Movie 130',
#   'Fantasy',
#   7.8,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'Actor A',
#   2020.0),
#  (1301,
#   'Movie 1301',
#   'Action',
#   8.4,
#   30.0,
#   150.0,
#   120.0,
#   'Scorsese',
#   'Actor D',
#   2016.0),
#  (1302,
#   'Movie 1302',
#   'Comedy',
#   6.0,
#   30.0,
#   20.0,
#   -10.0,
#   'Nolan',
#   'Actor E',
#   2016.0),
#  (1303,
#   'Movie 1303',
#   'Romance',
#   8.6,
#   10.0,
#   600.0,
#   590.0,
#   'Cameron',
#   'Actor A',
#   2018.0),
#  (1304,
#   'Movie 1304',
#   'Sci-Fi',
#   4.7,
#   30.0,
#   600.0,
#   570.0,
#   'Rajamouli',
#   'unknown',
#   2016.0),
#  (1305,
#   'Movie 1305',
#   'Drama',
#   7.9,
#   10.0,
#   150.0,
#   140.0,
#   'Scorsese',
#   'Actor C',
#   2018.0),
#  (1306,
#   'Movie 1306',
#   'Action',
#   5.4,
#   60.0,
#   600.0,
#   540.0,
#   'Scorsese',
#   'Actor A',
#   2019.0),
#  (1307,
#   'Movie 1307',
#   'Horror',
#   7.1,
#   60.0,
#   150.0,
#   90.0,
#   'Spielberg',
#   'Actor B',
#   2016.0),
#  (1308,
#   'Movie 1308',
#   'Romance',
#   5.5,
#   150.0,
#   150.0,
#   0.0,
#   'Tarantino',
#   'Actor A',
#   2017.0),
#  (5521,
#   'Movie 1309',
#   'Thriller',
#   6.6,
#   30.0,
#   80.0,
#   50.0,
#   'unknown',
#   'Actor B',
#   2022.0),
#  (131,
#   'Movie 131',
#   'Comedy',
#   4.0,
#   60.0,
#   80.0,
#   20.0,
#   'unknown',
#   'Actor E',
#   2018.0),
#  (1310,
#   'Movie 1310',
#   'Thriller',
#   6.3,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor D',
#   2022.0),
#  (1311,
#   'Movie 1311',
#   'Drama',
#   6.5,
#   150.0,
#   300.0,
#   150.0,
#   'Spielberg',
#   'Actor E',
#   2016.0),
#  (1312,
#   'Movie 1312',
#   'Fantasy',
#   9.4,
#   60.0,
#   150.0,
#   90.0,
#   'Scorsese',
#   'Actor A',
#   2019.0),
#  (1313,
#   'Movie 1313',
#   'Drama',
#   7.4,
#   150.0,
#   600.0,
#   450.0,
#   'Nolan',
#   'unknown',
#   2019.0),
#  (1314,
#   'Movie 1314',
#   'Romance',
#   7.5,
#   30.0,
#   80.0,
#   50.0,
#   'Scorsese',
#   'Actor B',
#   2018.0),
#  (1315,
#   'Movie 1315',
#   'Drama',
#   7.7,
#   10.0,
#   150.0,
#   140.0,
#   'Cameron',
#   'Actor A',
#   2016.0),
#  (1316,
#   'Movie 1316',
#   'Horror',
#   5.5,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'Actor D',
#   2015.0),
#  (1317,
#   'Movie 1317',
#   'Romance',
#   8.7,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'Actor C',
#   2018.0),
#  (1318,
#   'Movie 1318',
#   'Thriller',
#   4.1,
#   150.0,
#   20.0,
#   -130.0,
#   'Scorsese',
#   'Actor B',
#   2019.0),
#  (1319,
#   'Movie 1319',
#   'Thriller',
#   3.8,
#   150.0,
#   300.0,
#   150.0,
#   'Scorsese',
#   'Actor C',
#   2022.0),
#  (132,
#   'Movie 132',
#   'Romance',
#   4.4,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'Actor C',
#   2018.0),
#  (1320,
#   'Movie 1320',
#   'Fantasy',
#   6.6,
#   60.0,
#   300.0,
#   240.0,
#   'Scorsese',
#   'Actor B',
#   2021.0),
#  (1321,
#   'Movie 1321',
#   'Fantasy',
#   8.0,
#   100.0,
#   300.0,
#   200.0,
#   'unknown',
#   'Actor D',
#   2017.0),
#  (1322,
#   'Movie 1322',
#   'Drama',
#   7.4,
#   10.0,
#   80.0,
#   70.0,
#   'Spielberg',
#   'unknown',
#   2015.0),
#  (1323,
#   'Movie 1323',
#   'Comedy',
#   9.2,
#   30.0,
#   80.0,
#   50.0,
#   'Tarantino',
#   'Actor C',
#   2022.0),
#  (1325,
#   'Movie 1324',
#   'Comedy',
#   7.5,
#   150.0,
#   20.0,
#   -130.0,
#   'Scorsese',
#   'unknown',
#   2015.0),
#  (1324,
#   'Movie 1324',
#   'Sci-Fi',
#   4.4,
#   10.0,
#   600.0,
#   590.0,
#   'Tarantino',
#   'Actor A',
#   2021.0),
#  (5522,
#   'Movie 1326',
#   'Comedy',
#   8.5,
#   10.0,
#   300.0,
#   290.0,
#   'Nolan',
#   'Actor B',
#   2022.0),
#  (1327,
#   'Movie 1327',
#   'Sci-Fi',
#   3.7,
#   100.0,
#   600.0,
#   500.0,
#   'unknown',
#   'Actor C',
#   2015.0),
#  (1328,
#   'Movie 1328',
#   'Thriller',
#   8.6,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'Actor D',
#   2017.0),
#  (1329,
#   'Movie 1329',
#   'Thriller',
#   5.5,
#   150.0,
#   300.0,
#   150.0,
#   'Rajamouli',
#   'Actor D',
#   2016.0),
#  (133,
#   'Movie 133',
#   'Drama',
#   6.5,
#   10.0,
#   300.0,
#   290.0,
#   'Rajamouli',
#   'unknown',
#   2018.0),
#  (1330,
#   'Movie 1330',
#   'Action',
#   6.6,
#   100.0,
#   20.0,
#   -80.0,
#   'Spielberg',
#   'Actor E',
#   2018.0),
#  (1331,
#   'Movie 1331',
#   'Action',
#   6.3,
#   10.0,
#   20.0,
#   10.0,
#   'Nolan',
#   'Actor E',
#   2018.0),
#  (1332,
#   'Movie 1332',
#   'Horror',
#   7.8,
#   150.0,
#   600.0,
#   450.0,
#   'Scorsese',
#   'unknown',
#   2017.0),
#  (1333,
#   'Movie 1333',
#   'Thriller',
#   4.9,
#   60.0,
#   20.0,
#   -40.0,
#   'Nolan',
#   'Actor B',
#   2022.0),
#  (1334,
#   'Movie 1334',
#   'Action',
#   4.4,
#   150.0,
#   600.0,
#   450.0,
#   'Spielberg',
#   'Actor B',
#   2016.0),
#  (1335,
#   'Movie 1335',
#   'Drama',
#   6.8,
#   30.0,
#   150.0,
#   120.0,
#   'Cameron',
#   'Actor A',
#   2021.0),
#  (1336,
#   'Movie 1336',
#   'Action',
#   5.9,
#   60.0,
#   80.0,
#   20.0,
#   'unknown',
#   'Actor E',
#   2018.0),
#  (1337,
#   'Movie 1337',
#   'Drama',
#   4.0,
#   150.0,
#   150.0,
#   0.0,
#   'Nolan',
#   'Actor D',
#   2018.0),
#  (1338,
#   'Movie 1338',
#   'Horror',
#   4.0,
#   100.0,
#   80.0,
#   -20.0,
#   'Nolan',
#   'Actor E',
#   2020.0),
#  (1339,
#   'Movie 1339',
#   'Comedy',
#   6.8,
#   10.0,
#   300.0,
#   290.0,
#   'Scorsese',
#   'Actor D',
#   2019.0),
#  (134,
#   'Movie 134',
#   'Action',
#   9.1,
#   30.0,
#   600.0,
#   570.0,
#   'Spielberg',
#   'Actor B',
#   2019.0),
#  (1340,
#   'Movie 1340',
#   'Horror',
#   5.0,
#   60.0,
#   600.0,
#   540.0,
#   'Tarantino',
#   'Actor B',
#   2020.0),
#  (1341,
#   'Movie 1341',
#   'Sci-Fi',
#   7.8,
#   10.0,
#   150.0,
#   140.0,
#   'Rajamouli',
#   'unknown',
#   2015.0),
#  (1342,
#   'Movie 1342',
#   'Action',
#   4.9,
#   30.0,
#   20.0,
#   -10.0,
#   'Spielberg',
#   'Actor B',
#   2016.0),
#  (5523,
#   'Movie 1343',
#   'Comedy',
#   8.4,
#   10.0,
#   80.0,
#   70.0,
#   'Rajamouli',
#   'unknown',
#   2015.0),
#  (1344,
#   'Movie 1344',
#   'Drama',
#   4.7,
#   100.0,
#   150.0,
#   50.0,
#   'Scorsese',
#   'Actor C',
#   2016.0),
#  (1345,
#   'Movie 1345',
#   'Drama',
#   5.5,
#   30.0,
#   300.0,
#   270.0,
#   'Tarantino',
#   'Actor B',
#   2022.0),
#  (1346,
#   'Movie 1346',
#   'Sci-Fi',
#   5.2,
#   100.0,
#   150.0,
#   50.0,
#   'Tarantino',
#   'Actor B',
#   2019.0),
#  (1347,
#   'Movie 1347',
#   'Action',
#   5.8,
#   100.0,
#   600.0,
#   500.0,
#   'Tarantino',
#   'Actor D',
#   2018.0),
#  (1348,
#   'Movie 1348',
#   'Fantasy',
#   7.4,
#   100.0,
#   300.0,
#   200.0,
#   'Tarantino',
#   'Actor A',
#   2017.0),
#  (1350,
#   'Movie 1349',
#   'Fantasy',
#   3.7,
#   30.0,
#   150.0,
#   120.0,
#   'Spielberg',
#   'Actor B',
#   2015.0),
#  (1349,
#   'Movie 1349',
#   'Thriller',
#   6.5,
#   60.0,
#   300.0,
#   240.0,
#   'Tarantino',
#   'Actor D',
#   2020.0),
#  (135,
#   'Movie 135',
#   'Horror',
#   6.3,
#   100.0,
#   600.0,
#   500.0,
#   'unknown',
#   'Actor D',
#   2017.0),
#  (1351,
#   'Movie 1351',
#   'Sci-Fi',
#   8.2,
#   10.0,
#   20.0,
#   10.0,
#   'Scorsese',
#   'Actor A',
#   2017.0),
#  (1352,
#   'Movie 1352',
#   'Horror',
#   6.0,
#   30.0,
#   150.0,
#   120.0,
#   'Nolan',
#   'Actor B',
#   2016.0),
#  (1353,
#   'Movie 1353',
#   'Drama',
#   8.1,
#   30.0,
#   20.0,
#   -10.0,
#   'Rajamouli',
#   'Actor B',
#   2021.0),
#  (1354,
#   'Movie 1354',
#   'Romance',
#   9.3,
#   10.0,
#   600.0,
#   590.0,
#   'Scorsese',
#   'Actor E',
#   2020.0),
#  (1355,
#   'Movie 1355',
#   'Fantasy',
#   8.5,
#   150.0,
#   300.0,
#   150.0,
#   'unknown',
#   'Actor C',
#   2016.0),
#  (1356,
#   'Movie 1356',
#   'Action',
#   4.2,
#   10.0,
#   300.0,
#   290.0,
#   'Rajamouli',
#   'unknown',
#   2021.0),
#  (1357,
#   'Movie 1357',
#   'Romance',
#   9.1,
#   150.0,
#   80.0,
#   -70.0,
#   'Nolan',
#   'unknown',
#   2018.0),
#  (1358,
#   'Movie 1358',
#   'Comedy',
#   9.4,
#   100.0,
#   80.0,
#   -20.0,
#   'Nolan',
#   'Actor D',
#   2018.0),
#  (1359,
#   'Movie 1359',
#   'Romance',
#   5.9,
#   10.0,
#   80.0,
#   70.0,
#   'unknown',
#   'unknown',
#   2018.0),
#  (5524,
#   'Movie 136',
#   'Comedy',
#   7.3,
#   10.0,
#   150.0,
#   140.0,
#   'Rajamouli',
#   'Actor A',
#   2018.0),
#  (5525,
#   'Movie 1360',
#   'Sci-Fi',
#   8.2,
#   100.0,
#   600.0,
#   500.0,
#   'Tarantino',
#   'Actor C',
#   2017.0),
#  (1361,
#   'Movie 1361',
#   'Sci-Fi',
#   8.1,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'unknown',
#   2016.0),
#  (1362,
#   'Movie 1362',
#   'Sci-Fi',
#   7.2,
#   150.0,
#   150.0,
#   0.0,
#   'Tarantino',
#   'Actor E',
#   2016.0),
#  (1363,
#   'Movie 1363',
#   'Drama',
#   8.6,
#   60.0,
#   20.0,
#   -40.0,
#   'unknown',
#   'Actor D',
#   2018.0),
#  (1364,
#   'Movie 1364',
#   'Drama',
#   4.3,
#   60.0,
#   300.0,
#   240.0,
#   'unknown',
#   'unknown',
#   2022.0),
#  (1365,
#   'Movie 1365',
#   'Drama',
#   7.6,
#   60.0,
#   20.0,
#   -40.0,
#   'Scorsese',
#   'Actor A',
#   2016.0),
#  (1366,
#   'Movie 1366',
#   'Romance',
#   8.1,
#   150.0,
#   150.0,
#   0.0,
#   'Rajamouli',
#   'Actor D',
#   2017.0),
#  (1367,
#   'Movie 1367',
#   'Action',
#   8.0,
#   100.0,
#   150.0,
#   50.0,
#   'Spielberg',
#   'Actor D',
#   2022.0),
#  (1368,
#   'Movie 1368',
#   'Action',
#   6.6,
#   30.0,
#   150.0,
#   120.0,
#   'unknown',
#   'Actor C',
#   2016.0),
#  (1369,
#   'Movie 1369',
#   'Sci-Fi',
#   9.4,
#   60.0,
#   600.0,
#   540.0,
#   'Tarantino',
#   'Actor B',
#   2016.0),
#  (137,
#   'Movie 137',
#   'Action',
#   7.5,
#   30.0,
#   150.0,
#   120.0,
#   'unknown',
#   'Actor B',
#   2018.0),
#  (1370,
#   'Movie 1370',
#   'Thriller',
#   6.0,
#   30.0,
#   150.0,
#   120.0,
#   'Rajamouli',
#   'Actor D',
#   2022.0),
#  (1371,
#   'Movie 1371',
#   'Comedy',
#   4.0,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'Actor B',
#   2022.0),
#  (1372,
#   'Movie 1372',
#   'Horror',
#   6.9,
#   60.0,
#   600.0,
#   540.0,
#   'Scorsese',
#   'unknown',
#   2015.0),
#  (1373,
#   'Movie 1373',
#   'Romance',
#   3.8,
#   100.0,
#   80.0,
#   -20.0,
#   'unknown',
#   'unknown',
#   2022.0),
#  (1375,
#   'Movie 1374',
#   'Romance',
#   6.1,
#   100.0,
#   150.0,
#   50.0,
#   'unknown',
#   'Actor D',
#   2021.0),
#  (1376,
#   'Movie 1376',
#   'Sci-Fi',
#   4.4,
#   150.0,
#   150.0,
#   0.0,
#   'Cameron',
#   'unknown',
#   2022.0),
#  (5526,
#   'Movie 1377',
#   'Drama',
#   5.7,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'Actor E',
#   2016.0),
#  (1378,
#   'Movie 1378',
#   'Fantasy',
#   3.8,
#   60.0,
#   20.0,
#   -40.0,
#   'Tarantino',
#   'Actor E',
#   2019.0),
#  (1379,
#   'Movie 1379',
#   'Comedy',
#   6.4,
#   60.0,
#   300.0,
#   240.0,
#   'Tarantino',
#   'Actor B',
#   2019.0),
#  (138,
#   'Movie 138',
#   'Comedy',
#   6.2,
#   100.0,
#   300.0,
#   200.0,
#   'Rajamouli',
#   'Actor D',
#   2018.0),
#  (1380,
#   'Movie 1380',
#   'Romance',
#   4.2,
#   60.0,
#   150.0,
#   90.0,
#   'Spielberg',
#   'unknown',
#   2015.0),
#  (1381,
#   'Movie 1381',
#   'Thriller',
#   5.5,
#   10.0,
#   150.0,
#   140.0,
#   'unknown',
#   'Actor D',
#   2021.0),
#  (1382,
#   'Movie 1382',
#   'Horror',
#   5.8,
#   100.0,
#   20.0,
#   -80.0,
#   'Cameron',
#   'Actor C',
#   2017.0),
#  (1383,
#   'Movie 1383',
#   'Drama',
#   6.0,
#   150.0,
#   80.0,
#   -70.0,
#   'Cameron',
#   'Actor E',
#   2016.0),
#  (1384,
#   'Movie 1384',
#   'Drama',
#   3.6,
#   60.0,
#   600.0,
#   540.0,
#   'Scorsese',
#   'Actor E',
#   2020.0),
#  (1385,
#   'Movie 1385',
#   'Fantasy',
#   6.2,
#   100.0,
#   600.0,
#   500.0,
#   'Rajamouli',
#   'Actor A',
#   2020.0),
#  (1386,
#   'Movie 1386',
#   'Comedy',
#   3.5,
#   60.0,
#   300.0,
#   240.0,
#   'Cameron',
#   'Actor D',
#   2016.0),
#  (1387,
#   'Movie 1387',
#   'Sci-Fi',
#   6.6,
#   100.0,
#   20.0,
#   -80.0,
#   'Nolan',
#   'Actor C',
#   2022.0),
#  (1388,
#   'Movie 1388',
#   'Fantasy',
#   8.9,
#   30.0,
#   80.0,
#   50.0,
#   'Scorsese',
#   'Actor D',
#   2020.0),
#  (1389,
#   'Movie 1389',
#   'Comedy',
#   8.2,
#   150.0,
#   80.0,
#   -70.0,
#   'Scorsese',
#   'Actor B',
#   2021.0),
#  (139,
#   'Movie 139',
#   'Horror',
#   6.9,
#   30.0,
#   20.0,
#   -10.0,
#   'Cameron',
#   'Actor E',
#   2017.0),
#  (1390,
#   'Movie 1390',
#   'Fantasy',
#   6.1,
#   60.0,
#   300.0,
#   240.0,
#   'Nolan',
#   'Actor C',
#   2018.0),
#  (1391,
#   'Movie 1391',
#   'Sci-Fi',
#   5.3,
#   30.0,
#   150.0,
#   120.0,
#   'Nolan',
#   'Actor A',
#   2019.0),
#  (1392,
#   'Movie 1392',
#   'Drama',
#   3.9,
#   100.0,
#   150.0,
#   50.0,
#   'Tarantino',
#   'unknown',
#   2020.0),
#  (1393,
#   'Movie 1393',
#   'Horror',
#   9.1,
#   30.0,
#   150.0,
#   120.0,
#   'Tarantino',
#   'unknown',
#   2021.0),
#  (5527,
#   'Movie 1394',
#   'Fantasy',
#   4.8,
#   100.0,
#   20.0,
#   -80.0,
#   'Scorsese',
#   'unknown',
#   2017.0),
#  (1395,
#   'Movie 1395',
#   'Sci-Fi',
#   8.0,
#   150.0,
#   600.0,
#   450.0,
#   'Scorsese',
#   'Actor B',
#   2015.0),
#  (1396,
#   'Movie 1396',
#   'Horror',
#   8.8,
#   60.0,
#   80.0,
#   20.0,
#   'Spielberg',
#   'Actor A',
#   2020.0),
#  (1397,
#   'Movie 1397',
#   'Sci-Fi',
#   9.2,
#   150.0,
#   600.0,
#   450.0,
#   'Rajamouli',
#   'Actor C',
#   2018.0),
#  (1398,
#   'Movie 1398',
#   'Fantasy',
#   9.4,
#   30.0,
#   150.0,
#   120.0,
#   'Spielberg',
#   'Actor C',
#   2020.0),
#  (1400,
#   'Movie 1399',
#   'Comedy',
#   5.0,
#   100.0,
#   80.0,
#   -20.0,
#   'Scorsese',
#   'Actor A',
#   2015.0),
#  (1399,
#   'Movie 1399',
#   'Action',
#   5.0,
#   150.0,
#   300.0,
#   150.0,
#   'Cameron',
#   'Actor E',
#   2019.0),
#  (14,
#   'Movie 14',
#   'Drama',
#   7.7,
#   150.0,
#   150.0,
#   0.0,
#   'Cameron',
#   'Actor E',
#   2021.0),
#  (140,
#   'Movie 140',
#   'Drama',
#   8.7,
#   100.0,
#   80.0,
#   -20.0,
#   'Cameron',
#   'Actor B',
#   2018.0),
#  (1401,
#   'Movie 1401',
#   'Thriller',
#   4.3,
#   150.0,
#   20.0,
#   -130.0,
#   'Scorsese',
#   'Actor A',
#   2015.0),
#  (1402,
#   'Movie 1402',
#   'Action',
#   5.5,
#   60.0,
#   300.0,
#   240.0,
#   'Rajamouli',
#   'Actor C',
#   2015.0),
#  (1403,
#   'Movie 1403',
#   'Horror',
#   7.5,
#   150.0,
#   20.0,
#   -130.0,
#   'Nolan',
#   'Actor C',
#   2015.0),
#  (1404,
#   'Movie 1404',
#   'Thriller',
#   5.1,
#   10.0,
#   80.0,
#   70.0,
#   'Scorsese',
#   'Actor A',
#   2019.0),
#  (1405,
#   'Movie 1405',
#   'Sci-Fi',
#   4.3,
#   60.0,
#   300.0,
#   240.0,
#   'Cameron',
#   'Actor E',
#   2022.0),
#  (1406,
#   'Movie 1406',
#   'Horror',
#   6.4,
#   60.0,
#   80.0,
#   20.0,
#   'Rajamouli',
#   'Actor A',
#   2022.0),
#  (1407,
#   'Movie 1407',
#   'Horror',
#   9.2,
#   10.0,
#   20.0,
#   10.0,
#   'Spielberg',
# ...
#   2017.0),
#  (1769,
#   'Movie 1769',
#   'Thriller',
#   4.5,
#   150.0,
#   150.0,
#   0.0,
#   'Tarantino',
#   'Actor B',
#   2022.0),
#  (177,
#   'Movie 177',
#   'Romance',
#   5.9,
#   30.0,
#   20.0,
#   -10.0,
#   'Nolan',
#   'Actor B',
#   2019.0),
#  (1770,
#   'Movie 1770',
#   'Horror',
#   6.1,
#   60.0,
#   300.0,
#   240.0,
#   'unknown',
#   'Actor C',
#   2020.0),
#  (1771,
#   'Movie 1771',
#   'Drama',
#   8.8,
#   10.0,
#   80.0,
#   70.0,
#   'Nolan',
#   'Actor E',
#   2021.0),
#  (1772,
#   'Movie 1772',
#   'Thriller',
#   6.5,
#   30.0,
#   600.0,
#   570.0,
#   'Rajamouli',
#   'Actor C',
#   2021.0),
#  (1773,
#   'Movie 1773',
#   'Action',
#   6.7,
#   30.0,
#   300.0,
#   270.0,
#   'Scorsese',
#   'Actor A',
#   2019.0),
#  (1774,
#   'Movie 1774',
#   'Thriller',
#   5.0,
#   60.0,
#   600.0,
#   540.0,
#   'Scorsese',
#   'Actor D',
#   2016.0),
#  (1775,
#   'Movie 1774',
#   'Comedy',
#   6.3,
#   30.0,
#   20.0,
#   -10.0,
#   'Spielberg',
#   'Actor E',
#   2017.0),
#  (1776,
#   'Movie 1776',
#   'Action',
#   5.8,
#   150.0,
#   20.0,
#   -130.0,
#   'unknown',
#   'unknown',
#   2021.0),
#  (1777,
#   'Movie 1777',
#   'Fantasy',
#   5.6,
#   10.0,
#   150.0,
#   140.0,
#   'Nolan',
#   'Actor E',
#   2019.0),
#  (1778,
#   'Movie 1778',
#   'Romance',
#   7.9,
#   60.0,
#   20.0,
#   -40.0,
#   'Spielberg',
#   'Actor D',
#   2015.0),
#  (1779,
#   'Movie 1779',
#   'Comedy',
#   5.7,
#   30.0,
#   600.0,
#   570.0,
#   'Scorsese',
#   'Actor A',
#   2018.0),
#  (178,
#   'Movie 178',
#   'Comedy',
#   8.5,
#   150.0,
#   600.0,
#   450.0,
#   'Spielberg',
#   'Actor C',
#   2017.0),
#  (1780,
#   'Movie 1780',
#   'Romance',
#   6.0,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'Actor C',
#   2020.0),
#  (1781,
#   'Movie 1781',
#   'Drama',
#   5.7,
#   100.0,
#   80.0,
#   -20.0,
#   'Rajamouli',
#   'Actor C',
#   2017.0),
#  (1782,
#   'Movie 1782',
#   'Fantasy',
#   5.0,
#   30.0,
#   150.0,
#   120.0,
#   'Tarantino',
#   'Actor D',
#   2019.0),
#  (1783,
#   'Movie 1783',
#   'Action',
#   4.6,
#   150.0,
#   80.0,
#   -70.0,
#   'Cameron',
#   'unknown',
#   2020.0),
#  (1784,
#   'Movie 1784',
#   'Horror',
#   7.7,
#   10.0,
#   150.0,
#   140.0,
#   'unknown',
#   'Actor D',
#   2017.0),
#  (5553,
#   'Movie 1785',
#   'Thriller',
#   6.2,
#   60.0,
#   600.0,
#   540.0,
#   'Cameron',
#   'unknown',
#   2018.0),
#  (1786,
#   'Movie 1786',
#   'Thriller',
#   6.5,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'unknown',
#   2015.0),
#  (1787,
#   'Movie 1787',
#   'Fantasy',
#   3.9,
#   30.0,
#   600.0,
#   570.0,
#   'Spielberg',
#   'unknown',
#   2015.0),
#  (1788,
#   'Movie 1788',
#   'Sci-Fi',
#   9.4,
#   60.0,
#   300.0,
#   240.0,
#   'Rajamouli',
#   'Actor C',
#   2020.0),
#  (1789,
#   'Movie 1789',
#   'Horror',
#   7.2,
#   60.0,
#   300.0,
#   240.0,
#   'Cameron',
#   'Actor E',
#   2018.0),
#  (179,
#   'Movie 179',
#   'Drama',
#   7.3,
#   60.0,
#   600.0,
#   540.0,
#   'unknown',
#   'Actor E',
#   2019.0),
#  (1790,
#   'Movie 1790',
#   'Horror',
#   6.5,
#   60.0,
#   80.0,
#   20.0,
#   'Spielberg',
#   'Actor E',
#   2019.0),
#  (1791,
#   'Movie 1791',
#   'Thriller',
#   4.6,
#   150.0,
#   600.0,
#   450.0,
#   'Nolan',
#   'Actor E',
#   2017.0),
#  (1792,
#   'Movie 1792',
#   'Sci-Fi',
#   7.9,
#   30.0,
#   150.0,
#   120.0,
#   'Rajamouli',
#   'unknown',
#   2018.0),
#  (1793,
#   'Movie 1793',
#   'Romance',
#   6.2,
#   30.0,
#   150.0,
#   120.0,
#   'Scorsese',
#   'unknown',
#   2017.0),
#  (1794,
#   'Movie 1794',
#   'Sci-Fi',
#   6.1,
#   10.0,
#   600.0,
#   590.0,
#   'Cameron',
#   'Actor B',
#   2019.0),
#  (1795,
#   'Movie 1795',
#   'Romance',
#   4.3,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'unknown',
#   2018.0),
#  (1796,
#   'Movie 1796',
#   'Action',
#   8.9,
#   30.0,
#   80.0,
#   50.0,
#   'Cameron',
#   'Actor A',
#   2018.0),
#  (1797,
#   'Movie 1797',
#   'Horror',
#   4.3,
#   60.0,
#   150.0,
#   90.0,
#   'Cameron',
#   'Actor E',
#   2021.0),
#  (1798,
#   'Movie 1798',
#   'Comedy',
#   3.7,
#   100.0,
#   20.0,
#   -80.0,
#   'Nolan',
#   'Actor B',
#   2017.0),
#  (1799,
#   'Movie 1799',
#   'Romance',
#   7.9,
#   30.0,
#   20.0,
#   -10.0,
#   'Nolan',
#   'Actor A',
#   2015.0),
#  (1800,
#   'Movie 1799',
#   'Comedy',
#   5.4,
#   100.0,
#   150.0,
#   50.0,
#   'Rajamouli',
#   'Actor D',
#   2020.0),
#  (18,
#   'Movie 18',
#   'Drama',
#   9.2,
#   100.0,
#   600.0,
#   500.0,
#   'Spielberg',
#   'Actor E',
#   2017.0),
#  (180,
#   'Movie 180',
#   'Horror',
#   5.0,
#   60.0,
#   80.0,
#   20.0,
#   'Nolan',
#   'Actor C',
#   2017.0),
#  (1801,
#   'Movie 1801',
#   'Action',
#   3.9,
#   30.0,
#   20.0,
#   -10.0,
#   'Scorsese',
#   'Actor E',
#   2021.0),
#  (5554,
#   'Movie 1802',
#   'Thriller',
#   9.2,
#   150.0,
#   150.0,
#   0.0,
#   'Nolan',
#   'Actor A',
#   2021.0),
#  (1803,
#   'Movie 1803',
#   'Sci-Fi',
#   8.6,
#   30.0,
#   20.0,
#   -10.0,
#   'unknown',
#   'Actor D',
#   2018.0),
#  (1804,
#   'Movie 1804',
#   'Fantasy',
#   5.4,
#   150.0,
#   80.0,
#   -70.0,
#   'Tarantino',
#   'unknown',
#   2015.0),
#  (1805,
#   'Movie 1805',
#   'Thriller',
#   6.5,
#   60.0,
#   20.0,
#   -40.0,
#   'Cameron',
#   'Actor E',
#   2021.0),
#  (1806,
#   'Movie 1806',
#   'Thriller',
#   9.0,
#   10.0,
#   300.0,
#   290.0,
#   'Rajamouli',
#   'Actor A',
#   2018.0),
#  (1807,
#   'Movie 1807',
#   'Fantasy',
#   7.8,
#   60.0,
#   20.0,
#   -40.0,
#   'Spielberg',
#   'Actor D',
#   2016.0),
#  (1808,
#   'Movie 1808',
#   'Horror',
#   8.3,
#   100.0,
#   80.0,
#   -20.0,
#   'Spielberg',
#   'Actor B',
#   2016.0),
#  (1809,
#   'Movie 1809',
#   'Sci-Fi',
#   5.7,
#   30.0,
#   600.0,
#   570.0,
#   'Scorsese',
#   'unknown',
#   2018.0),
#  (181,
#   'Movie 181',
#   'Horror',
#   8.9,
#   60.0,
#   150.0,
#   90.0,
#   'Spielberg',
#   'Actor B',
#   2022.0),
#  (1810,
#   'Movie 1810',
#   'Fantasy',
#   5.9,
#   100.0,
#   150.0,
#   50.0,
#   'Rajamouli',
#   'Actor C',
#   2015.0),
#  (1811,
#   'Movie 1811',
#   'Thriller',
#   7.4,
#   10.0,
#   80.0,
#   70.0,
#   'unknown',
#   'Actor B',
#   2015.0),
#  (1812,
#   'Movie 1812',
#   'Romance',
#   6.5,
#   100.0,
#   300.0,
#   200.0,
#   'Cameron',
#   'Actor E',
#   2022.0),
#  (1813,
#   'Movie 1813',
#   'Romance',
#   3.5,
#   60.0,
#   20.0,
#   -40.0,
#   'Scorsese',
#   'unknown',
#   2015.0),
#  (1814,
#   'Movie 1814',
#   'Drama',
#   8.4,
#   60.0,
#   150.0,
#   90.0,
#   'Scorsese',
#   'unknown',
#   2016.0),
#  (1815,
#   'Movie 1815',
#   'Fantasy',
#   5.1,
#   150.0,
#   600.0,
#   450.0,
#   'Rajamouli',
#   'Actor C',
#   2021.0),
#  (1816,
#   'Movie 1816',
#   'Sci-Fi',
#   6.3,
#   10.0,
#   150.0,
#   140.0,
#   'Spielberg',
#   'Actor C',
#   2022.0),
#  (1817,
#   'Movie 1817',
#   'Horror',
#   6.9,
#   10.0,
#   20.0,
#   10.0,
#   'unknown',
#   'Actor D',
#   2022.0),
#  (1818,
#   'Movie 1818',
#   'Drama',
#   5.3,
#   60.0,
#   150.0,
#   90.0,
#   'Scorsese',
#   'Actor E',
#   2016.0),
#  (5555,
#   'Movie 1819',
#   'Drama',
#   9.4,
#   150.0,
#   150.0,
#   0.0,
#   'Scorsese',
#   'unknown',
#   2016.0),
#  (182,
#   'Movie 182',
#   'Drama',
#   6.1,
#   30.0,
#   80.0,
#   50.0,
#   'Rajamouli',
#   'Actor D',
#   2019.0),
#  (1820,
#   'Movie 1820',
#   'Fantasy',
#   4.2,
#   30.0,
#   600.0,
#   570.0,
#   'Cameron',
#   'Actor E',
#   2020.0),
#  (1821,
#   'Movie 1821',
#   'Action',
#   7.8,
#   150.0,
#   600.0,
#   450.0,
#   'Cameron',
#   'Actor D',
#   2016.0),
#  (1822,
#   'Movie 1822',
#   'Fantasy',
#   9.5,
#   60.0,
#   20.0,
#   -40.0,
#   'Scorsese',
#   'Actor C',
#   2018.0),
#  (1823,
#   'Movie 1823',
#   'Action',
#   7.3,
#   100.0,
#   20.0,
#   -80.0,
#   'Scorsese',
#   'Actor C',
#   2019.0),
#  (1825,
#   'Movie 1824',
#   'Fantasy',
#   8.2,
#   30.0,
#   150.0,
#   120.0,
#   'Nolan',
#   'Actor D',
#   2017.0),
#  (1824,
#   'Movie 1824',
#   'Comedy',
#   6.5,
#   60.0,
#   300.0,
#   240.0,
#   'Nolan',
#   'Actor D',
#   2020.0),
#  (1826,
#   'Movie 1826',
#   'Drama',
#   7.0,
#   150.0,
#   150.0,
#   0.0,
#   'Rajamouli',
#   'Actor E',
#   2021.0),
#  (1827,
#   'Movie 1827',
#   'Horror',
#   7.9,
#   10.0,
#   80.0,
#   70.0,
#   'unknown',
#   'unknown',
#   2019.0),
#  (1828,
#   'Movie 1828',
#   'Thriller',
#   4.6,
#   60.0,
#   300.0,
#   240.0,
#   'Scorsese',
#   'unknown',
#   2021.0),
#  (1829,
#   'Movie 1829',
#   'Fantasy',
#   7.8,
#   100.0,
#   150.0,
#   50.0,
#   'Scorsese',
#   'Actor C',
#   2017.0),
#  (183,
#   'Movie 183',
#   'Thriller',
#   8.0,
#   100.0,
#   150.0,
#   50.0,
#   'Rajamouli',
#   'Actor B',
#   2017.0),
#  (1830,
#   'Movie 1830',
#   'Fantasy',
#   5.9,
#   30.0,
#   80.0,
#   50.0,
#   'Rajamouli',
#   'unknown',
#   2016.0),
#  (1831,
#   'Movie 1831',
#   'Sci-Fi',
#   5.8,
#   60.0,
#   20.0,
#   -40.0,
#   'Spielberg',
#   'Actor A',
#   2021.0),
#  (1832,
#   'Movie 1832',
#   'Thriller',
#   5.5,
#   30.0,
#   150.0,
#   120.0,
#   'Cameron',
#   'Actor D',
#   2019.0),
#  (1833,
#   'Movie 1833',
#   'Horror',
#   5.8,
#   30.0,
#   600.0,
#   570.0,
#   'Scorsese',
#   'Actor D',
#   2015.0),
#  (1834,
#   'Movie 1834',
#   'Fantasy',
#   8.6,
#   10.0,
#   150.0,
#   140.0,
#   'Cameron',
#   'Actor A',
#   2021.0),
#  (1835,
#   'Movie 1835',
#   'Romance',
#   9.3,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'Actor B',
#   2016.0),
#  (5556,
#   'Movie 1836',
#   'Comedy',
#   4.7,
#   100.0,
#   150.0,
#   50.0,
#   'Cameron',
#   'Actor D',
#   2015.0),
#  (1837,
#   'Movie 1837',
#   'Horror',
#   4.5,
#   60.0,
#   300.0,
#   240.0,
#   'Spielberg',
#   'Actor E',
#   2019.0),
#  (1838,
#   'Movie 1838',
#   'Horror',
#   3.8,
#   150.0,
#   300.0,
#   150.0,
#   'Cameron',
#   'Actor D',
#   2019.0),
#  (1839,
#   'Movie 1839',
#   'Sci-Fi',
#   6.5,
#   60.0,
#   150.0,
#   90.0,
#   'Spielberg',
#   'Actor B',
#   2020.0),
#  (184,
#   'Movie 184',
#   'Sci-Fi',
#   7.7,
#   100.0,
#   300.0,
#   200.0,
#   'unknown',
#   'Actor C',
#   2019.0),
#  (1840,
#   'Movie 1840',
#   'Romance',
#   9.3,
#   150.0,
#   20.0,
#   -130.0,
#   'Tarantino',
#   'Actor B',
#   2016.0),
#  (1841,
#   'Movie 1841',
#   'Horror',
#   4.8,
#   30.0,
#   20.0,
#   -10.0,
#   'Cameron',
#   'Actor C',
#   2018.0),
#  (1842,
#   'Movie 1842',
#   'Horror',
#   9.3,
#   100.0,
#   20.0,
#   -80.0,
#   'Nolan',
#   'Actor E',
#   2018.0),
#  (1843,
#   'Movie 1843',
#   'Thriller',
#   6.5,
#   30.0,
#   600.0,
#   570.0,
#   'Cameron',
#   'Actor C',
#   2017.0),
#  (1844,
#   'Movie 1844',
#   'Sci-Fi',
#   3.6,
#   100.0,
#   300.0,
#   200.0,
#   'Rajamouli',
#   'Actor D',
#   2015.0),
#  (1845,
#   'Movie 1845',
#   'Sci-Fi',
#   8.1,
#   100.0,
#   300.0,
#   200.0,
#   'Nolan',
#   'unknown',
#   2020.0),
#  (1846,
#   'Movie 1846',
#   'Fantasy',
#   4.2,
#   60.0,
#   300.0,
#   240.0,
#   'Tarantino',
#   'Actor C',
#   2015.0),
#  (1847,
#   'Movie 1847',
#   'Horror',
#   5.2,
#   30.0,
#   300.0,
#   270.0,
#   'Cameron',
#   'Actor E',
#   2017.0),
#  (1848,
#   'Movie 1848',
#   'Thriller',
#   7.1,
#   30.0,
#   300.0,
#   270.0,
#   'Cameron',
#   'unknown',
#   2022.0),
#  (1849,
#   'Movie 1849',
#   'Fantasy',
#   6.4,
#   60.0,
#   300.0,
#   240.0,
#   'Rajamouli',
#   'Actor B',
#   2015.0),
#  (1850,
#   'Movie 1849',
#   'Action',
#   4.3,
#   30.0,
#   20.0,
#   -10.0,
#   'Tarantino',
#   'unknown',
#   2019.0),
#  (185,
#   'Movie 185',
#   'Thriller',
#   4.8,
#   30.0,
#   150.0,
#   120.0,
#   'Scorsese',
#   'Actor B',
#   2019.0),
#  (1851,
#   'Movie 1851',
#   'Romance',
#   3.9,
#   10.0,
#   150.0,
#   140.0,
#   'Scorsese',
#   'Actor B',
#   2022.0),
#  (1852,
#   'Movie 1852',
#   'Romance',
#   7.2,
#   60.0,
#   300.0,
#   240.0,
#   'Spielberg',
#   'Actor E',
#   2018.0),
#  (5557,
#   'Movie 1853',
#   'Fantasy',
#   6.6,
#   30.0,
#   80.0,
#   50.0,
#   'Nolan',
#   'unknown',
#   2018.0),
#  (1854,
#   'Movie 1854',
#   'Romance',
#   9.2,
#   60.0,
#   20.0,
#   -40.0,
#   'Tarantino',
#   'Actor D',
#   2016.0),
#  (1855,
#   'Movie 1855',
#   'Comedy',
#   4.9,
#   100.0,
#   20.0,
#   -80.0,
#   'Tarantino',
#   'Actor D',
#   2017.0),
#  (1856,
#   'Movie 1856',
#   'Thriller',
#   7.4,
#   60.0,
#   150.0,
#   90.0,
#   'unknown',
#   'Actor C',
#   2016.0),
#  (1857,
#   'Movie 1857',
#   'Drama',
#   5.6,
#   60.0,
#   600.0,
#   540.0,
#   'unknown',
#   'Actor C',
#   2018.0),
#  (1858,
#   'Movie 1858',
#   'Drama',
#   6.1,
#   150.0,
#   150.0,
#   0.0,
#   'Tarantino',
#   'Actor A',
#   2018.0),
#  (1859,
#   'Movie 1859',
#   'Drama',
#   9.0,
#   100.0,
#   150.0,
#   50.0,
#   'Spielberg',
#   'Actor B',
#   2017.0),
#  (186,
#   'Movie 186',
#   'Horror',
#   8.3,
#   10.0,
#   20.0,
#   10.0,
#   'Scorsese',
#   'Actor A',
#   2017.0),
#  (1860,
#   'Movie 1860',
#   'Comedy',
#   7.2,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'Actor A',
#   2021.0),
#  (1861,
#   'Movie 1861',
#   'Comedy',
#   3.7,
#   10.0,
#   20.0,
#   10.0,
#   'Scorsese',
#   'Actor B',
#   2015.0),
#  (1862,
#   'Movie 1862',
#   'Drama',
#   6.5,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'unknown',
#   2022.0),
#  (1863,
#   'Movie 1863',
#   'Action',
#   6.6,
#   60.0,
#   20.0,
#   -40.0,
#   'Cameron',
#   'unknown',
#   2018.0),
#  (1864,
#   'Movie 1864',
#   'Romance',
#   6.7,
#   100.0,
#   600.0,
#   500.0,
#   'unknown',
#   'Actor E',
#   2017.0),
#  (1865,
#   'Movie 1865',
#   'Sci-Fi',
#   7.0,
#   10.0,
#   150.0,
#   140.0,
#   'Spielberg',
#   'Actor C',
#   2020.0),
#  (1866,
#   'Movie 1866',
#   'Horror',
#   5.2,
#   10.0,
#   80.0,
#   70.0,
#   'Scorsese',
#   'Actor C',
#   2016.0),
#  (1867,
#   'Movie 1867',
#   'Action',
#   8.9,
#   10.0,
#   80.0,
#   70.0,
#   'Scorsese',
#   'Actor D',
#   2019.0),
#  (1868,
#   'Movie 1868',
#   'Romance',
#   6.8,
#   10.0,
#   600.0,
#   590.0,
#   'Tarantino',
#   'Actor C',
#   2017.0),
#  (1869,
#   'Movie 1869',
#   'Comedy',
#   5.0,
#   10.0,
#   600.0,
#   590.0,
#   'Spielberg',
#   'Actor C',
#   2022.0),
#  (5558,
#   'Movie 187',
#   'Sci-Fi',
#   9.0,
#   60.0,
#   150.0,
#   90.0,
#   'Spielberg',
#   'Actor B',
#   2015.0),
#  (5559,
#   'Movie 1870',
#   'Thriller',
#   4.1,
#   60.0,
#   20.0,
#   -40.0,
#   'Rajamouli',
#   'Actor A',
#   2016.0),
#  (1871,
#   'Movie 1871',
#   'Comedy',
#   8.1,
#   100.0,
#   600.0,
#   500.0,
#   'Scorsese',
#   'Actor C',
#   2016.0),
#  (1872,
#   'Movie 1872',
#   'Comedy',
#   5.0,
#   100.0,
#   150.0,
#   50.0,
#   'Cameron',
#   'Actor A',
#   2018.0),
#  (1873,
#   'Movie 1873',
#   'Comedy',
#   9.1,
#   60.0,
#   20.0,
#   -40.0,
#   'Tarantino',
#   'Actor D',
#   2021.0),
#  (1875,
#   'Movie 1874',
#   'Romance',
#   5.5,
#   100.0,
#   150.0,
#   50.0,
#   'Spielberg',
#   'unknown',
#   2015.0),
#  (1874,
#   'Movie 1874',
#   'Sci-Fi',
#   6.8,
#   150.0,
#   150.0,
#   0.0,
#   'Rajamouli',
#   'Actor C',
#   2021.0),
#  (1876,
#   'Movie 1876',
#   'Fantasy',
#   4.3,
#   60.0,
#   600.0,
#   540.0,
#   'Cameron',
#   'Actor E',
#   2016.0),
#  (1877,
#   'Movie 1877',
#   'Horror',
#   3.9,
#   60.0,
#   150.0,
#   90.0,
#   'Tarantino',
#   'Actor C',
#   2018.0),
#  (1878,
#   'Movie 1878',
#   'Drama',
#   5.3,
#   100.0,
#   150.0,
#   50.0,
#   'Scorsese',
#   'unknown',
#   2022.0),
#  (1879,
#   'Movie 1879',
#   'Horror',
#   7.6,
#   10.0,
#   80.0,
#   70.0,
#   'Nolan',
#   'Actor D',
#   2022.0),
#  (188,
#   'Movie 188',
#   'Fantasy',
#   3.6,
#   100.0,
#   600.0,
#   500.0,
#   'Cameron',
#   'Actor C',
#   2020.0),
#  (1880,
#   'Movie 1880',
#   'Thriller',
#   6.7,
#   60.0,
#   80.0,
#   20.0,
#   'Tarantino',
#   'Actor E',
#   2019.0),
#  (1881,
#   'Movie 1881',
#   'Drama',
#   6.5,
#   30.0,
#   80.0,
#   50.0,
#   'Scorsese',
#   'Actor C',
#   2015.0),
#  (1882,
#   'Movie 1882',
#   'Romance',
#   8.4,
#   60.0,
#   600.0,
#   540.0,
#   'Scorsese',
#   'Actor B',
#   2021.0),
#  (1883,
#   'Movie 1883',
#   'Thriller',
#   4.6,
#   60.0,
#   80.0,
#   20.0,
#   'unknown',
#   'Actor C',
#   2018.0),
#  (1884,
#   'Movie 1884',
#   'Drama',
#   5.2,
#   10.0,
#   300.0,
#   290.0,
#   'unknown',
#   'Actor A',
#   2018.0),
#  (1885,
#   'Movie 1885',
#   'Thriller',
#   9.4,
#   150.0,
#   600.0,
#   450.0,
#   'Cameron',
#   'Actor B',
#   2015.0),
#  (1886,
#   'Movie 1886',
#   'Thriller',
#   5.1,
#   100.0,
#   20.0,
#   -80.0,
#   'Nolan',
#   'unknown',
#   2022.0),
#  (5560,
#   'Movie 1887',
#   'Sci-Fi',
#   4.2,
#   30.0,
#   150.0,
#   120.0,
#   'Tarantino',
#   'unknown',
#   2018.0),
#  (1888,
#   'Movie 1888',
#   'Sci-Fi',
#   7.2,
#   30.0,
#   150.0,
#   120.0,
#   'Tarantino',
#   'unknown',
#   2022.0),
#  (1889,
#   'Movie 1889',
#   'Thriller',
#   5.2,
#   150.0,
#   150.0,
#   0.0,
#   'Tarantino',
#   'Actor D',
#   2021.0),
#  (189,
#   'Movie 189',
#   'Drama',
#   4.0,
#   150.0,
#   150.0,
#   0.0,
#   'Cameron',
#   'Actor A',
#   2022.0),
#  (1890,
#   'Movie 1890',
#   'Fantasy',
#   5.2,
#   150.0,
#   20.0,
#   -130.0,
#   'Cameron',
#   'Actor B',
#   2018.0),
#  (1891,
#   'Movie 1891',
#   'Romance',
#   5.1,
#   30.0,
#   600.0,
#   570.0,
#   'Nolan',
#   'Actor C',
#   2019.0),
#  (1892,
#   'Movie 1892',
#   'Action',
#   9.5,
#   100.0,
#   600.0,
#   500.0,
#   'Rajamouli',
#   'Actor A',
#   2019.0),
#  (1893,
#   'Movie 1893',
#   'Thriller',
#   6.1,
#   60.0,
#   600.0,
#   540.0,
#   'Spielberg',
#   'Actor E',
#   2017.0),
#  (1894,
#   'Movie 1894',
#   'Comedy',
#   4.5,
#   100.0,
#   300.0,
#   200.0,
#   'Rajamouli',
#   'Actor A',
#   2019.0),
#  (1895,
#   'Movie 1895',
#   'Horror',
#   9.2,
#   10.0,
#   600.0,
#   590.0,
#   'Scorsese',
#   'Actor B',
#   2022.0),
#  (1896,
#   'Movie 1896',
#   'Thriller',
#   9.2,
#   60.0,
#   150.0,
#   90.0,
#   'Nolan',
#   'unknown',
#   2018.0),
#  (1897,
#   'Movie 1897',
#   'Action',
#   8.6,
#   150.0,
#   150.0,
#   0.0,
#   'Rajamouli',
#   'Actor C',
#   2016.0),
#  (1898,
#   'Movie 1898',
#   'Comedy',
#   5.2,
#   60.0,
#   20.0,
#   -40.0,
#   'Rajamouli',
#   'Actor A',
#   2019.0),
#  (1900,
#   'Movie 1899',
#   'Romance',
#   6.5,
#   150.0,
#   150.0,
#   0.0,
#   'Spielberg',
#   'Actor A',
#   2016.0),
#  (1899,
#   'Movie 1899',
#   'Drama',
#   8.6,
#   60.0,
#   600.0,
#   540.0,
#   'Tarantino',
#   'Actor A',
#   2018.0),
#  (19,
#   'Movie 19',
#   'Drama',
#   6.5,
#   60.0,
#   80.0,
#   20.0,
#   'Cameron',
#   'Actor B',
#   2020.0),
#  (190,
#   'Movie 190',
#   'Action',
#   6.6,
#   60.0,
#   80.0,
#   20.0,
#   'Rajamouli',
#   'Actor B',
#   2022.0),
#  (1901,
#   'Movie 1901',
#   'Sci-Fi',
#   4.1,
#   30.0,
#   150.0,
#   120.0,
#   'Tarantino',
#   'Actor E',
#   2022.0),
#  (1902,
#   'Movie 1902',
#   'Sci-Fi',
#   5.9,
#   100.0,
#   20.0,
#   -80.0,
#   'unknown',
#   'Actor E',
#   2022.0),
#  ...]

# %%
cursor.executemany(insert_query,data)

# %%
connection.commit()

# %%
print("Rows inserted:", cursor.rowcount)
# Out:
# Rows inserted: 5473

# %%
query='''
SELECT
    release_year,
    title,
    gross_million
FROM (
    SELECT
        release_year,
        title,
        gross_million,
        ROW_NUMBER() OVER (
            PARTITION BY release_year
            ORDER BY gross_million DESC
        ) AS movie_rank
    FROM movies
) ranked_movies
WHERE movie_rank <= 10
ORDER BY release_year, gross_million DESC;'''

# %% [markdown]
# Get SQL result into Pandas

# %%
result=pd.read_sql(query,connection)
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_26172\2824243698.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result=pd.read_sql(query,connection)

# %%
result.head()
# Out:
#    release_year       title  gross_million
# 0          2015  Movie 5270          600.0
# 1          2015  Movie 5355          600.0
# 2          2015     Movie 4          600.0
# 3          2015    Movie 46          600.0
# 4          2015    Movie 79          600.0

# %%
plt.figure(figsize=(12, 6))

plt.bar(
    result["title"],
    result["gross_million"]
)

plt.xlabel("Movie")
plt.ylabel("Gross ($ Million)")
plt.title("Top 10 Highest-Grossing Movies by Year")

plt.xticks(rotation=90)

plt.tight_layout()

plt.show()

# %%
query_2="""
SELECT
    title,
    release_year,
    gross_million
FROM movies
WHERE gross_million IS NOT NULL
ORDER BY gross_million DESC, release_year DESC, title
LIMIT 10;
"""

# %%
result2=pd.read_sql(query_2,connection)
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_26172\3426641481.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result2=pd.read_sql(query_2,connection)

# %%
plt.figure(figsize=(12, 6))

plt.bar(
    result2["title"],
    result2["gross_million"]
)

plt.xlabel("Movie")
plt.ylabel("Gross ($ Million)")
plt.title("Top 10 Highest-Grossing Movies by Year")
# 
# plt.xticks(rotation=90)

plt.tight_layout()

plt.show()

# %%
query_3 = """
SELECT
    genre,
    rating
FROM movies
WHERE rating IS NOT NULL;
"""

# %%
result3=pd.read_sql(query_3,connection)
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_26172\3156414923.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result3=pd.read_sql(query_3,connection)

# %%
result3.boxplot(
    column="rating",
    by="genre"
)
plt.xlabel("Genre")
plt.ylabel("Rating")
plt.title("Rating Distribution Across Genres")

plt.suptitle("")

plt.show()

# %%
query_4 = """
SELECT
    director,
    AVG(rating) AS average_rating
FROM movies
WHERE rating IS NOT NULL  AND director <> 'Unknown'
GROUP BY director
ORDER BY average_rating DESC
LIMIT 5;
"""

# %%
result4 = pd.read_sql(query_4, connection)
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_26172\3314088242.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result4 = pd.read_sql(query_4, connection)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[172], line 1
# ----> 1 result4 = pd.read_sql(query_4, connection)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
#     701     if isinstance(pandas_sql, SQLiteDatabase):
# --> 702         return pandas_sql.read_query(
#     703             sql,
#     704             index_col=index_col,
#     705             params=params,
#     706             coerce_float=coerce_float,
#     707             parse_dates=parse_dates,
#     708             chunksize=chunksize,
#     709             dtype_backend=dtype_backend,
#     710             dtype=dtype,
#     711         )
#     713     try:
#     714         _is_table_name = pandas_sql.has_table(sql)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\sql.py:2809, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2798 def read_query(
#    2799     self,
#    2800     sql,
#    (...)   2807     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2808 ) -> DataFrame | Iterator[DataFrame]:
# -> 2809     cursor = self.execute(sql, params)
#    2810     columns = [col_desc[0] for col_desc in cursor.description]
#    2812     if chunksize is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\sql.py:2745, in SQLiteDatabase.execute(self, sql, params)
#    2743 cur = self.con.cursor()
#    2744 try:
# -> 2745     cur.execute(sql, *args)
#    2746     return cur
#    2747 except Error as exc:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\cursor.py:416, in MySQLCursor.execute(self, operation, params, map_results)
#     408 self._executed_list = self._stmt_partition["single_stmts"]
#     409 self._executed = (
#     410     self._stmt_partition["single_stmts"].popleft()
#     411     if map_results
#     412     else self._stmt_partition["mappable_stmt"]
#     413 )
#     415 self._handle_result(
# --> 416     self._connection.cmd_query(
#     417         self._stmt_partition["mappable_stmt"],
#     418         read_timeout=self._read_timeout,
#     419         write_timeout=self._write_timeout,
#     420     )
#     421 )
#     423 return None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\opentelemetry\context_propagation.py:97, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      95 # pylint: disable=possibly-used-before-assignment
#      96 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 97     return method(cnx, *args, **kwargs)
#      99 current_span = trace.get_current_span()
#     100 tp_header = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\_decorating.py:89, in handle_read_write_timeout.<locals>.decorator.<locals>.handle_cnx_method(cnx, *args, **kwargs)
#      87 if isinstance(err, TimeoutError):
#      88     cnx.close()
# ---> 89 raise err
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\_decorating.py:85, in handle_read_write_timeout.<locals>.decorator.<locals>.handle_cnx_method(cnx, *args, **kwargs)
#      80 @functools.wraps(cnx_method)
#      81 def handle_cnx_method(
#      82     cnx: "MySQLConnectionAbstract", *args: Any, **kwargs: Any
#      83 ) -> Any:
#      84     try:
# ---> 85         return cnx_method(cnx, *args, **kwargs)
#      86     except Exception as err:
#      87         if isinstance(err, TimeoutError):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\connection.py:984, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string, **kwargs)
#     981     read_timeout = kwargs.get("read_timeout", None)
#     982     write_timeout = kwargs.get("write_timeout", None)
# --> 984     result = self._handle_result(
#     985         self._send_cmd(
#     986             ServerCmd.QUERY,
#     987             query,
#     988             read_timeout=read_timeout,
#     989             write_timeout=write_timeout,
#     990         ),
#     991         read_timeout,
#     992         write_timeout,
#     993     )
#     994 except ProgrammingError as err:
#     995     if err.errno == 3948 and "Loading local data is disabled" in err.msg:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\_decorating.py:89, in handle_read_write_timeout.<locals>.decorator.<locals>.handle_cnx_method(cnx, *args, **kwargs)
#      87 if isinstance(err, TimeoutError):
#      88     cnx.close()
# ---> 89 raise err
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\_decorating.py:85, in handle_read_write_timeout.<locals>.decorator.<locals>.handle_cnx_method(cnx, *args, **kwargs)
#      80 @functools.wraps(cnx_method)
#      81 def handle_cnx_method(
#      82     cnx: "MySQLConnectionAbstract", *args: Any, **kwargs: Any
#      83 ) -> Any:
#      84     try:
# ---> 85         return cnx_method(cnx, *args, **kwargs)
#      86     except Exception as err:
#      87         if isinstance(err, TimeoutError):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\mysql\connector\connection.py:745, in MySQLConnection._handle_result(self, packet, read_timeout, write_timeout)
#     743     return self._handle_eof(packet)
#     744 if packet[4] == ERR_STATUS:
# --> 745     raise get_exception(packet)
#     747 # We have a text result set
#     748 column_count = self._protocol.parse_column_count(packet)
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'having director <> 'Unknown'
# LIMIT 5' at line 7

# %%
plt.bar(
    result4["director"],
    result4["average_rating"]
)

plt.xlabel("Director")
plt.ylabel("Average Rating")
plt.title("Top 5 Directors by Average Movie Rating")

plt.ylim(6, 7)

plt.show()

# %% [markdown]
# Problem statement
#
# Analyze budget vs gross correlation.

# %%
query_5 = """
SELECT
    budget_million,
    gross_million
FROM movies

"""

# %%
result5 = pd.read_sql(query_5, connection)
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_26172\3689223710.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   result5 = pd.read_sql(query_5, connection)

# %%
correlation = result5["budget_million"].corr(
    result5["gross_million"]
)

print("Correlation:", correlation)
# Out:
# Correlation: 0.00521697747102233

# %%
plt.figure(figsize=(10, 6))

plt.scatter(
    result5["budget_million"],
    result5["gross_million"]
)

plt.xlabel("Budget ($ Million)")
plt.ylabel("Gross ($ Million)")
plt.title("Budget vs Gross Revenue")


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[181], line 3
#       1 plt.figure(figsize=(10, 6))
# ----> 3 plt.scatter(
#       4     result5["budget_million"],
#       5     correlation
#       6 )
#       8 plt.xlabel("Budget ($ Million)")
#       9 plt.ylabel("Gross ($ Million)")
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\pyplot.py:4128, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    4108 @_copy_docstring_and_deprecators(Axes.scatter)
#    4109 def scatter(
#    4110     x: float | ArrayLike,
#    (...)   4126     **kwargs,
#    4127 ) -> PathCollection:
# -> 4128     __ret = gca().scatter(
#    4129         x,
#    4130         y,
#    4131         s=s,
#    4132         c=c,
#    4133         marker=marker,
#    4134         cmap=cmap,
#    4135         norm=norm,
#    4136         vmin=vmin,
#    4137         vmax=vmax,
#    4138         alpha=alpha,
#    4139         linewidths=linewidths,
#    4140         edgecolors=edgecolors,
#    4141         colorizer=colorizer,
#    4142         plotnonfinite=plotnonfinite,
#    4143         **({"data": data} if data is not None else {}),
#    4144         **kwargs,
#    4145     )
#    4146     sci(__ret)
#    4147     return __ret
#
#     [... skipping hidden 2 frame]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\axes\_axes.py:5329, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    5327 y = np.ma.ravel(y)
#    5328 if x.size != y.size:
# -> 5329     raise ValueError("x and y must be the same size")
#    5331 if s is None:
#    5332     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    5333          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size
